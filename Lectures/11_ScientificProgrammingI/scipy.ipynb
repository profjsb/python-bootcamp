# %%
import scipy
print(scipy.__doc__)
# Out:
# SciPy: A scientific computing package for Python
# ...
#
# Documentation is available in the docstrings and
# online at http://docs.scipy.org.
#
# Contents
# --------
# SciPy imports all the functions from the NumPy namespace, and in
# addition provides:
#
# Subpackages
# -----------
# Using any of these subpackages requires an explicit import.  For example,
# ``import scipy.cluster``.
#
# ::
#
#  cluster                      --- Vector Quantization / Kmeans
#  fftpack                      --- Discrete Fourier Transform algorithms
#  integrate                    --- Integration routines
#  interpolate                  --- Interpolation Tools
#  io                           --- Data input and output
#  linalg                       --- Linear algebra routines
#  linalg.blas                  --- Wrappers to BLAS library
#  linalg.lapack                --- Wrappers to LAPACK library
#  misc                         --- Various utilities that don't have
# ...

# %% [markdown]
# ## Tutorial index
#
# - [scipy.fft -- analyze the melodic tones of the unladen African swallow](scipy_fft.ipynb)
# - [scipy.ndimage -- count bubbles on a microscope scan](scipy_ndimage.ipynb)
# - [scipy.spatial -- dissect a dinosaur, geometrically speaking of course](scipy_spatial.ipynb)
# - [scipy.linalg_sparse -- compute PageRank on a graph](scipy_linalg_sparse.ipynb)
#
# ## Breakout
#
# Since we didn't get to them before, we'll do the NumPy breakouts today.
#
# - [2D FFT filtering](../05_NumpyPandasMatplotlib/Exercise-FourierImageDenoise.ipynb)
# - [Numerical integration](../05_NumpyPandasMatplotlib/Exercise-TrapezoidRule.ipynb)

# %% [markdown]
# ## A note on contributing to open source

# %%
from scipy import optimize
print(optimize.__doc__)
# Out:
# ...
# Optimization and root finding (:mod:`scipy.optimize`)
# ...
#
# .. currentmodule:: scipy.optimize
#
# Optimization
# ...
#
# Local Optimization
# ------------------
#
# .. autosummary::
#    :toctree: generated/
#
#    minimize - Unified interface for minimizers of multivariate functions
#    minimize_scalar - Unified interface for minimizers of univariate functions
#    OptimizeResult - The optimization result returned by some optimizers
#
# The `minimize` function supports the following methods:
#
# .. toctree::
#
#    optimize.minimize-neldermead
#    optimize.minimize-powell
#    optimize.minimize-cg
#    optimize.minimize-bfgs
#    optimize.minimize-newtoncg
#    optimize.minimize-lbfgsb
#    optimize.minimize-tnc
#    optimize.minimize-cobyla
#    optimize.minimize-slsqp
#    optimize.minimize-dogleg
#    optimize.minimize-trustncg
#
# The `minimize_scalar` function supports the following methods:
#
# .. toctree::
#
#    optimize.minimize_scalar-brent
#    optimize.minimize_scalar-bounded
# ...
