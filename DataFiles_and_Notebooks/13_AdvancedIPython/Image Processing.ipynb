# %% [markdown]
# # Image Manipulation with skimage

# %% [markdown]
# This example builds a simple UI for performing basic image manipulation with [scikit-image](http://scikit-image.org/).

# %%
from IPython.html.widgets import interact, interactive, fixed
from IPython.display import display
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
import skimage
from skimage import data, filters, io

# %%
i = data.coffee()
i.shape
# Out:
# (400, 600, 3)

# %%
io.Image(i)
# Out:
# Image([[[ 21,  13,   8],
#         [ 21,  13,   9],
#         [ 20,  11,   8],
#         ...,
#         [228, 182, 138],
#         [231, 185, 142],
#         [228, 184, 140]],
#
#        [[ 21,  13,   7],
#         [ 21,  13,   9],
#         [ 20,  14,   7],
#         ...,
#         [228, 182, 136],
#         [231, 185, 139],
#         [229, 183, 137]],
#
#        [[ 21,  14,   7],
#         [ 23,  13,  10],
#         [ 20,  14,   9],
#         ...,
#         [228, 182, 136],
#         [228, 184, 137],
#         [229, 185, 138]],
#
#        ...,
#        [[189, 124,  77],
#         [214, 155, 109],
#         [197, 141, 100],
#         ...,
#         [165,  86,  37],
#         [161,  82,  41],
#         [143,  67,  29]],
#
#        [[207, 148, 102],
#         [201, 142,  99],
#         [196, 140,  97],
#         ...,
#         [154,  74,  37],
#         [147,  66,  33],
#         [145,  65,  31]],
#
#        [[197, 141, 100],
#         [195, 137,  99],
#         [193, 138,  98],
#         ...,
#         [158,  73,  38],
#         [144,  64,  30],
#         [143,  60,  29]]], dtype=uint8)

# %% [markdown]
# In Python 3, you can use the new function annotation syntax to describe widgets for interact:

# %%
lims = (0.0,1.0,0.01)

@interact
def edit_image(image: fixed(i), σ:(0.0,10.0,0.1)=0.1, 
               r:lims=1.0, g:lims=1.0, b:lims=1.0) :
    new_image = filter.gaussian_filter(image, sigma=σ, multichannel=True)
    new_image[:,:,0] = r*new_image[:,:,0]
    new_image[:,:,1] = g*new_image[:,:,1]
    new_image[:,:,2] = b*new_image[:,:,2]
    new_image = io.Image(new_image)
    display(new_image)
    return new_image
# Out:
# Image([[[ 0.02381208,  0.02095885,  0.01795519],
#         [ 0.02382119,  0.02103371,  0.01834385],
#         [ 0.02387857,  0.02122297,  0.01866892],
#         ...,
#         [ 0.25802467,  0.29108896,  0.31163383],
#         [ 0.25891539,  0.29293576,  0.3138313 ],
#         [ 0.25945088,  0.29429279,  0.31546284]],
#
#        [[ 0.0238049 ,  0.0210068 ,  0.01741845],
#         [ 0.023824  ,  0.02109428,  0.0178722 ],
#         [ 0.02388992,  0.02128906,  0.01828352],
#         ...,
#         [ 0.25759991,  0.29043062,  0.31017738],
#         [ 0.25859693,  0.29242307,  0.31266791],
#         [ 0.25923449,  0.29392228,  0.31459599]],
#
#        [[ 0.0237605 ,  0.02097665,  0.01682162],
#         [ 0.02379262,  0.02107548,  0.01732408],
#         [ 0.02387093,  0.02127374,  0.01780586],
#         ...,
#         [ 0.25697626,  0.28949905,  0.30857257],
#         [ 0.25805082,  0.29156547,  0.31123937],
#         [ 0.25877065,  0.29315844,  0.31337777]],
#
#        ...,
#        [[ 0.21762403,  0.21387094,  0.20714939],
#         [ 0.21929259,  0.21665692,  0.21103856],
#         [ 0.221089  ,  0.21989012,  0.21537318],
#         ...,
#         [ 0.17293865,  0.11413175,  0.07533719],
#         [ 0.17258995,  0.11341731,  0.07482547],
#         [ 0.17165152,  0.11224506,  0.07409217]],
#
#        [[ 0.21995513,  0.21752099,  0.21245824],
#         [ 0.22120676,  0.21973705,  0.21570118],
#         [ 0.22265165,  0.22244626,  0.21944483],
#         ...,
#         [ 0.1730856 ,  0.11340935,  0.07499528],
#         [ 0.17193979,  0.11180258,  0.07394574],
#         [ 0.17032921,  0.10986396,  0.0727749 ]],
#
#        [[ 0.22183508,  0.22086987,  0.21766992],
#         [ 0.22270667,  0.22245022,  0.22009722],
#         [ 0.22389184,  0.22464823,  0.22317619],
#         ...,
#         [ 0.17297824,  0.11236223,  0.07443428],
#         [ 0.17126515,  0.11010272,  0.07304889],
#         [ 0.16923132,  0.10764542,  0.07163957]]])
