# %% [markdown]
# # Querying Craigslist with Python
# ## Overview
# In this notebook, I'll show you how to make a simple query on Craigslist using some nifty python modules. You can take advantage of all the structure data that exists on webpages to collect interesting datasets.

# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# First we need to figure out how to submit a query to Craigslist. As with many websites, one way you can do this is simply by constructing the proper URL and sending it to Craigslist. Here's a sample URL that is returned after manually typing in a search to Craigslist:
#
# `http://sfbay.craigslist.org/search/eby/apa?bedrooms=1&pets_cat=1&pets_dog=1&is_furnished=1`
#
# This is actually two separate things. The first tells craigslist what kind of thing we're searching for:
#
# `http://sfbay.craigslist.org/search/eby/apa` says we're searching in the sfbay area (`sfbay`) for apartments (`apa`) in the east bay (`eby`).
#
# The second part contains the parameters that we pass to the search:
#
# `?bedrooms=1&pets_cat=1&pets_dog=1&is_furnished=1` says we want 1+ bedrooms, cats allowed, dogs allowed, and furnished apartments. You can manually change these fields in order to create new queries.
#
# So, we'll use this knowledge to send some custom URLs to Craigslist. We'll do this using the `requests` python module, which is really useful for querying websites.

# %%
import requests

# %% [markdown]
# In internet lingo, we're posting a `get` requests to the website, which simply says that we'd like to get some information from the Craigslist website.  With requests, we can easily create a dictionary that specifies parameters in the URL:

# %%
url_base = 'http://sfbay.craigslist.org/search/eby/apa'
params = dict(bedrooms=1, is_furnished=1)
rsp = requests.get(url_base, params=params)

# %%
# Note that requests automatically created the right URL:
print(rsp.url)
# Out:
# http://sfbay.craigslist.org/search/eby/apa?bedrooms=1&is_furnished=1

# %%
# We can access the content of the response that Craigslist sent back here:
print(rsp.text)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js"><head>
#     <title>SF bay area apartments / housing rentals  - craigslist</title>
#
#     <meta name="description" content="SF bay area apartments / housing rentals  - craigslist">
#     <link rel="canonical" href="https://sfbay.craigslist.org/search/eby/apa">
#     <link rel="alternate" type="application/rss+xml" href="https://sfbay.craigslist.org/search/eby/apa?bedrooms=1&amp;is_furnished=1&amp;format=rss" title="RSS feed for craigslist | SF bay area apartments / housing rentals  - craigslist ">
#
#
#     <meta name="viewport" content="initial-scale=1.0, user-scalable=1">
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=a593a03f11256e897b1b6294bfc3cbef">
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocs.css?v=d89a7dd9d708acf29a54986eb8b11bda">
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/jquery-ui-1.9.2.custom.css?v=86db72e37d2cf63cab3c63485c71becb">
#     <link rel="prefetch" href="//www.craigslist.org/js/postings-concat.min.js?v=2c267741ac82581ef0aff79d8144768b">
#
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/leaflet-stock.css?v=969bf0c010aad78a472cb96ed5c1d1bc">
# <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/MarkerCluster.css?v=c9937ed03fbb57f185493cd8c283efeb">
# <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps.css?v=0713fba1eea156d1e29815594450b352">
# <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">
# <![endif]-->
#
#         <script type="text/javascript"><!--
#             var expiredFavIDs = [];
# var subarea = "eby";
# var maxResults = 2500;
# var lessInfoText = "less info";
# var showMapTabs = 1;
# var areaID = "1";
# var starHint = "save this post in your favorites list";
# var sectionAbb = "hhh";
# var catAbb = "apa";
# var currencySymbol = "&#x0024;";
# var areaRegion = "CA";
# var noImageText = "no image";
# var sectionBase = "hhh";
# var showInfoText = "show info";
# var zoomToPosting = null;
# var imageHost = "http://images.craigslist.org";
# var areaCountry = "US";
# var countOfTotalText = "image {count} of {total}";
# var pID = null;
#
#         --></script>
#
#     <!--[if lt IE 9]>
# <script src="//www.craigslist.org/js/html5shiv.min.js?v=096822b653643ed1af3136947e4ea79a" type="text/javascript" ></script>
# <![endif]-->
# <!--[if lte IE 7]>
# <script src="//www.craigslist.org/js/json2.min.js?v=178d4ad319e0e0b4a451b15e49b71bec" type="text/javascript" ></script>
# <![endif]-->
# </head>
#
# <body class="toc  search">
#   <script type="text/javascript"><!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         var lng = C('cl_def_lang');
#         if (lng) bodyClassList.push(lng);
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof sectionAbb !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(sectionAbb + ':([^,]+)', 'i')) || {})[1];
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# --></script>
#
#
#   <section id="pagecontainer">
#     <div class="bglogo"></div>
#
#
# <header class="bchead mobile-header">
#     <div class="mobile-menu-button">menu</div>
#     <h2 class="mobile-logo">
#         <a class="mobile-logo-link" href="/">craigslist</a> &gt; housing
#     </h2>
# </header>
#
# <nav class="breadcrumbs-container closed bchead">
#     <form id="breadcrumbform" method="get" action="/search/eby/apa" data-action="/search/###/apa">
#         <input type="hidden" name="is_furnished" value="1"><input type="hidden" name="bedrooms" value="1">
#         <div class="breadbox">
#             <ul class="userlinks">
#     <li class="user post">
#         <a class="no-mobile" href="https://post.craigslist.org/c/sfo?lang=en">post</a>
#         <a class="mobile-only" href="https://post.craigslist.org/c/sfo?lang=en">post to classifieds</a>
#     </li>
#     <li class="user account">
#         <em>[ </em>
#         <a class="no-mobile" href="https://accounts.craigslist.org/login/home">account</a>
#         <a class="mobile-only" href="https://accounts.craigslist.org/login/home">my account</a>
#         <em> ]</em>
#     </li>
#     <li class="user fav">
#         <div class="favorites">
#
#     <a href="#" class="favlink"><span class="n">0</span><span class="no-mobile"> favorites</span></a>
# </div>
#     </li>
# </ul>
#             <ul class="breadcrumbs">
#                 <li class="crumb cl"><a href="/">CL</a></li><li class="crumb area"><label for="areaAbb" class="mobile-only submenu-text">area</label><span class="no-js"><a href="/">SF bay area</a></span>
# <select name="areaAbb" id="areaAbb" class="js-only">
#     <option value="sfbay">SF bay area</option>
#     <option value="bakersfield">bakersfield</option>
#     <option value="chico">chico</option>
#     <option value="fresno">fresno</option>
#     <option value="goldcountry">gold country</option>
#     <option value="hanford">hanford</option>
#     <option value="mendocino">mendocino co</option>
#     <option value="merced">merced</option>
#     <option value="modesto">modesto</option>
#     <option value="monterey">monterey</option>
#     <option value="redding">redding</option>
#     <option value="reno">reno</option>
#     <option value="sacramento">sacramento</option>
#     <option value="slo">san luis obispo</option>
#     <option value="santamaria">santa maria</option>
#     <option value="stockton">stockton</option>
#     <option value="susanville">susanville</option>
#     <option value="visalia">visalia-tulare</option>
#     <option value="yubasutter">yuba-sutter</option>
# </select>
#  <span class="breadcrumb-arrow">&gt;</span></li><li class="crumb subarea"><label for="subArea" class="mobile-only submenu-text">subarea</label><select id="subArea" name="subArea">
#     <option value="">all SF bay area</option>
#     <option value="eby" selected>east bay</option>
#     <option value="nby">north bay</option>
#     <option value="pen">peninsula</option>
#     <option value="sfc">san francisco</option>
#     <option value="scz">santa cruz</option>
#     <option value="sby">south bay</option>
# </select>
#  <span class="breadcrumb-arrow">&gt;</span></li><li class="crumb section"><label for="catAbb" class="mobile-only submenu-text">section</label><select name="catAbb" id="catAbb">
#     <option value="ccc">community</option>
#     <option value="eee">events</option>
#     <option value="sss">for sale</option>
#     <option value="ggg">gigs</option>
#     <option value="hhh" selected>housing</option>
#     <option value="jjj">jobs</option>
#     <option value="ppp">personals</option>
#     <option value="rrr">resumes</option>
#     <option value="bbb">services</option>
# </select>
#  <span class="breadcrumb-arrow">&gt;</span></li><li class="crumb category"><div class="mobile-only breadcrumb-labels">category</div><select id="subcatAbb" class="js-only">
#     <option value="hhh">all</option>
# <option value="apa" selected>apts/housing for rent</option>
# <option value="hou">apts wanted</option>
# <option value="swp">housing swap</option>
# <option value="off">office & commercial</option>
# <option value="prk">parking & storage</option>
# <option value="reb">real estate - by broker</option>
# <option value="reo">real estate - by owner</option>
# <option value="rew">real estate wanted</option>
# <option value="roo">rooms & shares</option>
# <option value="sha">rooms wanted</option>
# <option value="sub">sublets & temporary</option>
# <option value="sbw">sublet/temp wanted</option>
# <option value="vac">vacation rentals</option>
# </select><span class="no-js">apts/housing for rent</span> <span class="no-js"> <input type="submit" value="go"></span></li>
#             </ul>
#         </div>
#         <div class="clearfix"></div>
#     </form>
# </nav>
#
#     <div class="middle">
#       <form id="searchform" action="/search/eby/apa">
#         <div class="searchbox">
#           <input id="excats" type="hidden" name="excats">
#
#           <div class="searchgroup showoptions linklike closed">
#             <span class="open">&ndash;</span><span class="closed">+</span> categories & options
#             <div class="mobile-favorites mobile-only"><div class="favorites">
#
#     <a href="#" class="favlink"><span class="n">0</span><span class="no-mobile"> favorites</span></a>
# </div></div>
#           </div>
#           <div class="searchoptions closed">
#
#
#         <script type="text/javascript"><!--
#             var odaCats = {};
#
#         --></script>
#
#     <div class="searchgroup categories">
#         <div class="cattitle"><a href="/search/eby/apa" title="clear all search parameters" class="reset">apartments / housing rentals</a></div>
#
#     </div>
#             <input type="hidden" name="is_paid" id="is_paid" value="">
#
#             <div class="searchgroup">
#             <ul><li><label class="srchType"><input type="checkbox" name="srchType" class="autosubmit" value="T" >search titles only</label></li><li><label class="hasPic"><input type="checkbox" name="hasPic" class="autosubmit" value="1" >has image</label></li><li><label class="postedToday"><input type="checkbox" name="postedToday" class="autosubmit" value="1" >posted today</label></li></ul>
#
#             <ul class="js-only nearbyAreas ">
#
#             </ul>
#             </div>
#             <div class="searchgroup">      <div id="headerattr_nh" class="catfilter attr_picker multilink "
#             data-checked-count="0" data-attr="nh">
#         <span id="plusminus_nh" class="plusminus">+</span>neighborhoods
#       </div>
# <ul id="ul_nh" class="attr_list hideme">           <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="alameda_46" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="46" type="checkbox">
#                alameda
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="albany_/_el_cerrito_47" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="47" type="checkbox">
#                albany / el cerrito
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="berkeley_48" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="48" type="checkbox">
#                berkeley
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="berkeley_north_/_hills_49" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="49" type="checkbox">
#                berkeley north / hills
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="brentwood_/_oakley_142" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="142" type="checkbox">
#                brentwood / oakley
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="concord_/_pleasant_hill_/_martinez_51" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="51" type="checkbox">
#                concord / pleasant hill / martinez
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="danville_/_san_ramon_52" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="52" type="checkbox">
#                danville / san ramon
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="dublin_/_pleasanton_/_livermore_53" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="53" type="checkbox">
#                dublin / pleasanton / livermore
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="emeryville_112" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="112" type="checkbox">
#                emeryville
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="fairfield_/_vacaville_154" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="154" type="checkbox">
#                fairfield / vacaville
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="fremont_/_union_city_/_newark_54" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="54" type="checkbox">
#                fremont / union city / newark
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="hayward_/_castro_valley_55" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="55" type="checkbox">
#                hayward / castro valley
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="hercules,_pinole,_san_pablo,_el_sob_56" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="56" type="checkbox">
#                hercules, pinole, san pablo, el sob
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="lafayette_/_orinda_/_moraga_57" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="57" type="checkbox">
#                lafayette / orinda / moraga
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="oakland_downtown_58" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="58" type="checkbox">
#                oakland downtown
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="oakland_east_59" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="59" type="checkbox">
#                oakland east
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="oakland_hills_/_mills_60" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="60" type="checkbox">
#                oakland hills / mills
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="oakland_lake_merritt_/_grand_61" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="61" type="checkbox">
#                oakland lake merritt / grand
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="oakland_north_/_temescal_62" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="62" type="checkbox">
#                oakland north / temescal
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="oakland_piedmont_/_montclair_63" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="63" type="checkbox">
#                oakland piedmont / montclair
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="oakland_rockridge_/_claremont_66" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="66" type="checkbox">
#                oakland rockridge / claremont
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="oakland_west_64" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="64" type="checkbox">
#                oakland west
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="pittsburg_/_antioch_113" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="113" type="checkbox">
#                pittsburg / antioch
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="richmond_/_point_/_annex_65" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="65" type="checkbox">
#                richmond / point / annex
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="san_leandro_67" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="67" type="checkbox">
#                san leandro
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="vallejo_/_benicia_68" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="68" type="checkbox">
#                vallejo / benicia
#              </label>
#            </li>
#            <li class="attr_nh ">
#              <label data-attr="nh">
#                <input id="walnut_creek_69" name="nh"
#                       class="multi_checkbox multi_nh" data-attr="nh"
#
#                       value="69" type="checkbox">
#                walnut creek
#              </label>
#            </li>
# <li class="selectall js-only attr_nh "><label><input type="checkbox" data-attr="nh" class="selectallcb multi_checkbox" > <span class="all select_all_nh">select all</span><span class="none deselect_all_nh">deselect all</span></label></li></ul></div>
#
#             <div class="searchgroup minmax ">
#   <span class="searchfieldlabel">price</span> <input type="tel" name="min_price" class="flatinput min" placeholder="min" title="whole number, no letters or symbols" value=""> <input type="tel" name="max_price" class="flatinput max" placeholder="max" title="whole number, no letters or symbols" value="">
# </div>
# <div class="searchgroup">
#   <select name="bedrooms" class="autosubmit">
#     <option value="">all bedrooms</option>
#     <option value="1" selected="selected">1+ bedrooms</option>
# <option value="2">2+ bedrooms</option>
# <option value="3">3+ bedrooms</option>
# <option value="4">4+ bedrooms</option>
# <option value="5">5+ bedrooms</option>
# <option value="6">6+ bedrooms</option>
# <option value="7">7+ bedrooms</option>
# <option value="8">8+ bedrooms</option>
#
#   </select>
#   <br>
#   <select name="bathrooms" class="autosubmit">
#     <option value="">all bathrooms</option>
#     <option value="1">1+ bathrooms</option>
# <option value="2">2+ bathrooms</option>
# <option value="3">3+ bathrooms</option>
# <option value="4">4+ bathrooms</option>
# <option value="5">5+ bathrooms</option>
# <option value="6">6+ bathrooms</option>
# <option value="7">7+ bathrooms</option>
# <option value="8">8+ bathrooms</option>
#
#   </select>
# </div><div class="searchgroup minmax ">
#   <span class="searchfieldlabel">ft<sup>2</sup></span> <input type="tel" name="minSqft" class="flatinput min" placeholder="min" title="whole number, no letters or symbols" value=""> <input type="tel" name="maxSqft" class="flatinput max" placeholder="max" title="whole number, no letters or symbols" value="">
# </div><div class="searchgroup"><label class="pets_cat"><input type="checkbox" name="pets_cat" value="1"  class="autosubmit">cats ok</label><br><label class="pets_dog"><input type="checkbox" name="pets_dog" value="1"  class="autosubmit">dogs ok</label><br><label class="is_furnished"><input type="checkbox" name="is_furnished" value="1"  class="autosubmit" checked="checked">furnished</label><br><label class="no_smoking"><input type="checkbox" name="no_smoking" value="1"  class="autosubmit">no smoking</label><br><label class="wheelchaccess"><input type="checkbox" name="wheelchaccess" value="1"  class="autosubmit">wheelchair access</label><br></div><div class="searchgroup">      <div id="headerattr_housing_type" class="catfilter attr_picker multilink "
#             data-checked-count="0" data-attr="housing_type">
#         <span id="plusminus_housing_type" class="plusminus">+</span>housing type
#       </div>
# <ul id="ul_housing_type" class="attr_list hideme">           <li class="attr_housing_type ">
#              <label data-attr="housing_type">
#                <input id="apartment_1" name="housing_type"
#                       class="multi_checkbox multi_housing_type" data-attr="housing_type"
#
#                       value="1" type="checkbox">
#                apartment
#              </label>
#            </li>
#            <li class="attr_housing_type ">
#              <label data-attr="housing_type">
#                <input id="condo_2" name="housing_type"
#                       class="multi_checkbox multi_housing_type" data-attr="housing_type"
#
#                       value="2" type="checkbox">
#                condo
#              </label>
#            </li>
#            <li class="attr_housing_type ">
#              <label data-attr="housing_type">
#                <input id="cottage/cabin_3" name="housing_type"
#                       class="multi_checkbox multi_housing_type" data-attr="housing_type"
#
#                       value="3" type="checkbox">
#                cottage/cabin
#              </label>
#            </li>
#            <li class="attr_housing_type ">
#              <label data-attr="housing_type">
#                <input id="duplex_4" name="housing_type"
#                       class="multi_checkbox multi_housing_type" data-attr="housing_type"
#
#                       value="4" type="checkbox">
#                duplex
#              </label>
#            </li>
#            <li class="attr_housing_type ">
#              <label data-attr="housing_type">
#                <input id="flat_5" name="housing_type"
#                       class="multi_checkbox multi_housing_type" data-attr="housing_type"
#
#                       value="5" type="checkbox">
#                flat
#              </label>
#            </li>
#            <li class="attr_housing_type ">
#              <label data-attr="housing_type">
#                <input id="house_6" name="housing_type"
#                       class="multi_checkbox multi_housing_type" data-attr="housing_type"
#
#                       value="6" type="checkbox">
#                house
#              </label>
#            </li>
#            <li class="attr_housing_type ">
#              <label data-attr="housing_type">
#                <input id="in-law_7" name="housing_type"
#                       class="multi_checkbox multi_housing_type" data-attr="housing_type"
#
#                       value="7" type="checkbox">
#                in-law
#              </label>
#            </li>
#            <li class="attr_housing_type ">
#              <label data-attr="housing_type">
#                <input id="loft_8" name="housing_type"
#                       class="multi_checkbox multi_housing_type" data-attr="housing_type"
#
#                       value="8" type="checkbox">
#                loft
#              </label>
#            </li>
#            <li class="attr_housing_type ">
#              <label data-attr="housing_type">
#                <input id="townhouse_9" name="housing_type"
#                       class="multi_checkbox multi_housing_type" data-attr="housing_type"
#
#                       value="9" type="checkbox">
#                townhouse
#              </label>
#            </li>
#            <li class="attr_housing_type ">
#              <label data-attr="housing_type">
#                <input id="manufactured_10" name="housing_type"
#                       class="multi_checkbox multi_housing_type" data-attr="housing_type"
#
#                       value="10" type="checkbox">
#                manufactured
#              </label>
#            </li>
#            <li class="attr_housing_type ">
#              <label data-attr="housing_type">
#                <input id="assisted_living_11" name="housing_type"
#                       class="multi_checkbox multi_housing_type" data-attr="housing_type"
#
#                       value="11" type="checkbox">
#                assisted living
#              </label>
#            </li>
#            <li class="attr_housing_type ">
#              <label data-attr="housing_type">
#                <input id="land_12" name="housing_type"
#                       class="multi_checkbox multi_housing_type" data-attr="housing_type"
#
#                       value="12" type="checkbox">
#                land
#              </label>
#            </li>
# <li class="selectall js-only attr_housing_type "><label><input type="checkbox" data-attr="housing_type" class="selectallcb multi_checkbox" > <span class="all select_all_housing_type">select all</span><span class="none deselect_all_housing_type">deselect all</span></label></li></ul>      <div id="headerattr_laundry" class="catfilter attr_picker multilink "
#             data-checked-count="0" data-attr="laundry">
#         <span id="plusminus_laundry" class="plusminus">+</span>laundry
#       </div>
# <ul id="ul_laundry" class="attr_list hideme">           <li class="attr_laundry ">
#              <label data-attr="laundry">
#                <input id="w/d_in_unit_1" name="laundry"
#                       class="multi_checkbox multi_laundry" data-attr="laundry"
#
#                       value="1" type="checkbox">
#                w/d in unit
#              </label>
#            </li>
#            <li class="attr_laundry ">
#              <label data-attr="laundry">
#                <input id="w/d_hookups_4" name="laundry"
#                       class="multi_checkbox multi_laundry" data-attr="laundry"
#
#                       value="4" type="checkbox">
#                w/d hookups
#              </label>
#            </li>
#            <li class="attr_laundry ">
#              <label data-attr="laundry">
#                <input id="laundry_in_bldg_2" name="laundry"
#                       class="multi_checkbox multi_laundry" data-attr="laundry"
#
#                       value="2" type="checkbox">
#                laundry in bldg
#              </label>
#            </li>
#            <li class="attr_laundry ">
#              <label data-attr="laundry">
#                <input id="laundry_on_site_3" name="laundry"
#                       class="multi_checkbox multi_laundry" data-attr="laundry"
#
#                       value="3" type="checkbox">
#                laundry on site
#              </label>
#            </li>
#            <li class="attr_laundry ">
#              <label data-attr="laundry">
#                <input id="no_laundry_on_site_5" name="laundry"
#                       class="multi_checkbox multi_laundry" data-attr="laundry"
#
#                       value="5" type="checkbox">
#                no laundry on site
#              </label>
#            </li>
# </ul>      <div id="headerattr_parking" class="catfilter attr_picker multilink "
#             data-checked-count="0" data-attr="parking">
#         <span id="plusminus_parking" class="plusminus">+</span>parking
#       </div>
# <ul id="ul_parking" class="attr_list hideme">           <li class="attr_parking ">
#              <label data-attr="parking">
#                <input id="carport_1" name="parking"
#                       class="multi_checkbox multi_parking" data-attr="parking"
#
#                       value="1" type="checkbox">
#                carport
#              </label>
#            </li>
#            <li class="attr_parking ">
#              <label data-attr="parking">
#                <input id="attached_garage_2" name="parking"
#                       class="multi_checkbox multi_parking" data-attr="parking"
#
#                       value="2" type="checkbox">
#                attached garage
#              </label>
#            </li>
#            <li class="attr_parking ">
#              <label data-attr="parking">
#                <input id="detached_garage_3" name="parking"
#                       class="multi_checkbox multi_parking" data-attr="parking"
#
#                       value="3" type="checkbox">
#                detached garage
#              </label>
#            </li>
#            <li class="attr_parking ">
#              <label data-attr="parking">
#                <input id="off-street_parking_4" name="parking"
#                       class="multi_checkbox multi_parking" data-attr="parking"
#
#                       value="4" type="checkbox">
#                off-street parking
#              </label>
#            </li>
#            <li class="attr_parking ">
#              <label data-attr="parking">
#                <input id="street_parking_5" name="parking"
#                       class="multi_checkbox multi_parking" data-attr="parking"
#
#                       value="5" type="checkbox">
#                street parking
#              </label>
#            </li>
#            <li class="attr_parking ">
#              <label data-attr="parking">
#                <input id="valet_parking_6" name="parking"
#                       class="multi_checkbox multi_parking" data-attr="parking"
#
#                       value="6" type="checkbox">
#                valet parking
#              </label>
#            </li>
#            <li class="attr_parking ">
#              <label data-attr="parking">
#                <input id="no_parking_7" name="parking"
#                       class="multi_checkbox multi_parking" data-attr="parking"
#
#                       value="7" type="checkbox">
#                no parking
#              </label>
#            </li>
# <li class="selectall js-only attr_parking "><label><input type="checkbox" data-attr="parking" class="selectallcb multi_checkbox" > <span class="all select_all_parking">select all</span><span class="none deselect_all_parking">deselect all</span></label></li></ul></div><div class="searchgroup">
#   <div class="label">open house date</div>
#   <select class="autosubmit" id="sale_date" name="sale_date">
#      <option></option>
#      <option value="2015-08-21">aug 21 - today</option><option value="2015-08-22">aug 22 - tomorrow</option><option value="2015-08-23">aug 23 - sunday</option><option value="2015-08-24">aug 24 - monday</option><option value="2015-08-25">aug 25 - tuesday</option><option value="2015-08-26">aug 26 - wednesday</option><option value="2015-08-27">aug 27 - thursday</option><option value="2015-08-28">aug 28 - friday</option><option value="2015-08-29">aug 29 - saturday</option><option value="2015-08-30">aug 30 - sunday</option><option value="2015-08-31">aug 31 - monday</option><option value="2015-09-01">sep 1 - tuesday</option><option value="2015-09-02">sep 2 - wednesday</option><option value="2015-09-03">sep 3 - thursday</option>
#   </select>
# </div>
#               <div class="searchgroup resetsearch">
#                 <a href="/search/eby/apa" title="clear all search parameters" class="reset linklike">reset</a>
#                 <button type="submit" class="searchlink linklike">search</button>
#               </div>
#             </div>
#
#             <div class="no-mobile">
#
#             </div>
#           </div>
#
#           <div class="rightpane">
#             <div class="querybox">
#
#               <span class="form-tab js-only"><span class="search-open" title="hide search">&laquo;</span><span class="search-closed" title="show search">&raquo;</span></span>
#               <input type="text" placeholder="search apartments / housing rentals" name="query"
#                      id="query" value="" autocorrect="off"
#                      autocapitalize="off" autocomplete="off" data-autocomplete="search"
#                      class="flatinput ui-autocomplete-input">
#               <button type="submit" class="searchbtn"><span class="searchicon"></span></button>
#               <div class="savealert">
#                    <a class="saveme no-mobile" data-action="alert" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Falert%3FURL%3Dhttps%253A%252F%252Fsfbay%252Ecraigslist%252Eorg%252Fsearch%252Feby%252Fapa%253Fbedrooms%253D1%2526is%255Ffurnished%253D1" title="save this search with email alerts ">email alert</a>
#                    <a class="saveme no-mobile" data-action="save" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Fsfbay%252Ecraigslist%252Eorg%252Fsearch%252Feby%252Fapa%253Fbedrooms%253D1%2526is%255Ffurnished%253D1" title="save this search ">save search</a>
#                    <a class="saveme mobile-only" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Falert%3FURL%3Dhttps%253A%252F%252Fsfbay%252Ecraigslist%252Eorg%252Fsearch%252Feby%252Fapa%253Fbedrooms%253D1%2526is%255Ffurnished%253D1">search alert</a>
#                 </div>
#             </div>
#             <div class="toc_legend">
#               <div class="center">
#                 <div class="tocview"><span class="buttongroup js-only"><a href="#list" title="show results in a list" class="mode button" data-view="list" id="listview">list</a><a href="#pic" title="show results in a list with thumbnail pictures" class="mode button" data-view="pic" id="picview">thumb</a><a href="#grid" title="show results side-by-side with larger pictures" class="mode button" data-view="grid" id="gridview">gallery</a><a href="#map" title="show results on a map" class="mode button" data-view="map" id="mapview">map</a></span></div><div class="tocsort"><span class="buttongroup"><span class="button sel">newest</span><a class="button" title="sort by price, lowest to highest" href="/search/eby/apa?sort=priceasc&bedrooms=1&amp;is_furnished=1"><span class='pricesort'><span class='pricesort'>&#x0024;</span>&#x0024;</span>&#x0024;</a><a class="button" title="sort by price, highest to lowest" href="/search/eby/apa?sort=pricedsc&bedrooms=1&amp;is_furnished=1">&#x0024;<span class='pricesort'>&#x0024;<span class='pricesort'>&#x0024;</span></span></a></span></div><span class="paginator buttongroup  firstpage lastpage"><span class="resulttotal">displaying <span class="displaycount">...</span> <span class="of-total">of <span class="totalcount">84</span></span> postings</span><span class="buttons"><a href="/search/eby/apa?bedrooms=1&amp;is_furnished=1" class="button first" title="first page">&lt;&lt;</a><span class="button first" title="first page">&lt;&lt;</span><a href="/search/eby/apa?bedrooms=1&amp;is_furnished=1" class="button prev" title="previous page">&lt; prev</a><span class="button prev" title="previous page">&lt; prev</span><span class="button pagenum"><span class="range"><span class="rangeFrom">1</span> to <span class="rangeTo">84</span></span> <span class="of-total">of <span class="totalcount">84</span></span></span><a href="/search/eby/apa?s=84&amp;bedrooms=1&amp;is_furnished=1" class="button next" title="next page"> next &gt; </a><span class="button next" title="next page"> next &gt; </span></span></span>
#               </div>
#
#             </div>
#             <div class="content">
#               <section class="favlistsection">
#                 <section class="favlistinfo">
#
#
#                 </section>
#               </section>
#
#
#
#
#
#               <p class="row" data-pid="5183961779"> <a href="/eby/apa/5183961779.html" class="i" data-ids="0:00f0f_4VOyuRKg1NL,0:00d0d_cPsrSIKZ65M,0:00101_49n5wQ2FpPz,0:00L0L_cdHq3zu3Vg5,0:00H0H_lGZouxLZlnS"></a> <span class="txt"> <span class="star"></span> <span class="pl"> <time datetime="2015-08-21 12:13" title="Fri 21 Aug 12:13:51 PM">Aug 21</time> <a href="/eby/apa/5183961779.html" data-id="5183961779" class="hdrlnk">North Berkeley Furnished In-Law</a> </span> <span class="l2"> <span class="price">$990</span> <span class="housing">/ 1br - </span> <span class="pnr"> <small> (berkeley north / hills)</small> <span class="px"> <span class="p"> pic <span class="maptag" data-pid="5183961779">map</span></span></span> </span> </span> <span class="js-only banish-unbanish no-mobile">[<a class="banish" title="hide" data-pid="5183961779">x</a><a class="unbanish linklike" title="unhide" data-pid="5183961779">undo</a>]</span> </span> </p><p class="row" data-pid="5183952420" data-repost-of="3041402814"> <a href="/eby/apa/5183952420.html" class="i"></a> <span class="txt"> <span class="star"></span> <span class="pl"> <time datetime="2015-08-21 12:08" title="Fri 21 Aug 12:08:58 PM">Aug 21</time> <a href="/eby/apa/5183952420.html" data-id="5183952420" class="hdrlnk">Sunny Townhouse unit on quiet street can be furnished</a> </span> <span class="l2"> <span class="price">$2300</span> <span class="housing">/ 2br - 700ft<sup>2</sup> - </span> <span class="pnr"> <small> (berkeley)</small> <span class="px"> <span class="p"> <span class="maptag" data-pid="5183952420">map</span></span></span> </span> </span> <span class="js-only banish-unbanish no-mobile">[<a class="banish" title="hide" data-pid="5183952420">x</a><a class="unbanish linklike" title="unhide" data-pid="5183952420">undo</a>]</span> </span> </p><p class="row" data-pid="5183881696"> <a href="/eby/apa/5183881696.html" class="i" data-ids="0:00r0r_cTxkpzEvod8,0:00o0o_a4xg37PaxFt,0:00s0s_4CNMAdBCluS,0:00G0G_kOol9aNIFQM,0:00C0C_1TscT7X7zYd,0:00d0d_lfUXtL9AwWG"></a> <span class="txt"> <span class="star"></span> <span class="pl"> <time datetime="2015-08-21 11:29" title="Fri 21 Aug 11:29:57 AM">Aug 21</time> <a href="/eby/apa/5183881696.html" data-id="5183881696" class="hdrlnk">Modern 1br Condo Furnished Avail Sept 10 - Nov 10</a> </span> <span class="l2"> <span class="price">$2450</span> <span class="housing">/ 1br - 800ft<sup>2</sup> - </span> <span class="pnr"> <small> (emeryville)</small> <span class="px"> <span class="p"> pic <span class="maptag" data-pid="5183881696">map</span></span></span> </span> </span> <span class="js-only banish-unbanish no-mobile">[<a class="banish" title="hide" data-pid="5183881696">x</a><a class="unbanish linklike" title="unhide" data-pid="5183881696">undo</a>]</span> </span> </p><p class="row" data-pid="5183619662"> <a href="/eby/apa/5183619662.html" class="i" data-ids="0:00f0f_5AOqcodDiee"></a> <span class="txt"> <span class="star"></span> <span class="pl"> <time datetime="2015-08-21 11:07" title="Fri 21 Aug 11:07:52 AM">Aug 21</time> <a href="/eby/apa/5183619662.html" data-id="5183619662" class="hdrlnk">Fantastic deal for this 3 bedrooms house</a> </span> <span class="l2"> <span class="price">$2415</span> <span class="housing">/ 3br - 1148ft<sup>2</sup> - </span> <span class="pnr"> <small> (fremont / union city / newark)</small> <span class="px"> <span class="p"> pic <span class="maptag" data-pid="5183619662">map</span></span></span> </span> </span> <span class="js-only banish-unbanish no-mobile">[<a class="banish" title="hide" data-pid="5183619662">x</a><a class="unbanish linklike" title="unhide" data-pid="5183619662">undo</a>]</span> </span> </p><p class="row" data-pid="5156905843"> <a href="/eby/apa/5156905843.html" class="i" data-ids="0:00Q0Q_lfnMchLtf3q,0:00L0L_uuLmYWgxkW,0:00B0B_hSyixyGxFhp,0:00f0f_xPIBbgXfL6,0:00202_bKSpDpzV6bA,0:01616_30JEWHoGJFo,0:01616_30JEWHoGJFo,0:00z0z_167JWq5C0lx,0:00r0r_b0IdMEKQ6Ka,0:00t0t_kFzFia7LpiR,0:00606_cXxPlM9Q8WF,0:00G0G_ ...
#               <div id="mapcontainer" data-arealat="37.500000" data-arealon="-122.250000">
#     <div id="noresult_overlay"></div>
#         <div id="noresult_text">
#             <span class="message">No mappable items found</span>
#         </div>
#     <div id="map" class="loading"><div class="closeFS">&times;</div></div>
# </div>
#
#               <div class="toc_legend bottom">
#                 <div class="center">
#                   <div class="tocview">
#                     <span class="buttongroup"><a class="backtotop button" href="#pagecontainer">^ back to top</a></span>
#                   </div>
#                   <div class="tocsort">
#                     <span class="buttongroup"><a class="backtotop button" href="#pagecontainer">^ back to top</a></span>
#                   </div>
#                   <span class="paginator buttongroup  firstpage lastpage"><span class="resulttotal">displaying <span class="displaycount">...</span> <span class="of-total">of <span class="totalcount">84</span></span> postings</span><span class="buttons"><a href="/search/eby/apa?bedrooms=1&amp;is_furnished=1" class="button first" title="first page">&lt;&lt;</a><span class="button first" title="first page">&lt;&lt;</span><a href="/search/eby/apa?bedrooms=1&amp;is_furnished=1" class="button prev" title="previous page">&lt; prev</a><span class="button prev" title="previous page">&lt; prev</span><span class="button pagenum"><span class="range"><span class="rangeFrom">1</span> to <span class="rangeTo">84</span></span> <span class="of-total">of <span class="totalcount">84</span></span></span><a href="/search/eby/apa?s=84&amp;bedrooms=1&amp;is_furnished=1" class="button next" title="next page"> next &gt; </a><span class="button next" title="next page"> next &gt; </span></span></span>
#                 </div>
#               </div>
#             </div>
#           </div>
#           <section class="blurbs">
#
#           </section>
#
#           <div id="floater">
#             <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#             <img class="payload" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#           </div>
#           <template id="gallerycarousel">
#             <div class="sliderinfo"></div><div class="sliderback arrow">&lt;</div><div class="sliderforward arrow">&gt;</div>
#           </template>
#         </form>
#       </div>
#     <div class="mobile-only">
#
#     </div>
#
#
#     <div class="discards footstool no-mobile js-only">
#     <p>
#         <strong class="hidden_count"></strong> hidden
#     </p>
#
#     <!-- show if there is at least one hidden thing and the hidden are NOT revealed -->
#     <div class="show-discards-link linklike" role="button" tabindex="0">click to show</div>
#
#     <!-- show if there is at least one hidden thing and the hidden ARE not revealed -->
#     <div class="hide-discards-link linklike" role="button" tabindex="0">click to hide</div>
# </div>
#
#     <footer>
#
#             <span class="rss">
#                 <a class="l" href="https://sfbay.craigslist.org/search/eby/apa?bedrooms=1&amp;is_furnished=1&amp;format=rss">RSS</a>
#                 <a href="http://www.craigslist.org/about/rss">(?)</a><br>
#             </span>
#
#     <ul class="clfooter">
#         <li>&copy; 2015 <span class="desktop">craigslist</span><span class="mobile">CL</span></li>
#         <li><a href="//www.craigslist.org/about/help/">help</a></li>
#         <li><a href="//www.craigslist.org/about/scams">safety</a></li>
#         <li class="desktop"><a href="//www.craigslist.org/about/privacy.policy">privacy</a></li>
#         <li class="desktop"><a href="https://forums.craigslist.org/?forumID=8">feedback</a></li>
#         <li class="desktop"><a href="//www.craigslist.org/about/craigslist_is_hiring">cl jobs</a></li>
#         <li><a href="//www.craigslist.org/about/terms.of.use">terms</a></li>
#         <li><a href="//www.craigslist.org/about/">about</a></li>
#         <li class="fsel desktop linklike" data-mode="mobile">mobile</li>
#         <li class="fsel mobile linklike" data-mode="regular">desktop</li>
#     </ul>
# </footer>
#   </section>
#   <script src="//www.craigslist.org/js/general-concat.min.js?v=7db13e14edce1be55946b402b4ae2132" type="text/javascript" ></script>
#   <script type="text/javascript"><!--
#         var iframe = document.createElement('iframe');
#         iframe.style.display = 'none';
#         iframe.src = '//www.' + CL.url.baseDomain + '/static/localstorage.html?v=51a29e41f8e978141e4085ed4a77d170';
#         document.body.insertBefore(iframe, null);
#     --></script>
#   <script type="text/template" id="clustertemplate">
#     <li class="posting {visited}" data-id="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#          <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#          <span class="bedrooms">{BedroomsContent}</span>
#          <span class="postingtitle"><a>{PostingTitle}</a></span>
#          <span class="js-only map-banish-unbanish no-mobile" data-pid="{PostingID}">
#           [<a class="banish" id="banisher" data-pid="{PostingID}" title="hide">x</a><a class="unbanish" id="unbanisher" data-pid="{PostingID}" title="unhide">undo</a>]
#          </span>
#         </div>
#     </li>
# </script>
# <script type="text/template" id="postingtemplate">
#     <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             <button class="back" type="button">&lt;</button> back to posting list
#         </div>
#         <div class="title">
#             <span class="star" data-pid="{PostingID}"></span>
#             <span class="postingtitle">
#               <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish no-mobile single">
#                   [<a class="banish" id="banisher" data-pid="{PostingID}" title="hide">x</a><a class="unbanish" id="unbanisher" data-pid="{PostingID}" title="unhide">undo</a>]
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer">
#             <div class="slidernav">
#                 <span class="sliderback">&lt;</span><span class="sliderinfo"></span><span class="sliderforward">&gt;</span>
#             </div>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <abbr class="date timeago" title="{isoPostedDate}">{humanPostedDate}</abbr>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
# </script>
# <script type="text/template" id="popuptemplate">
#     <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
# </script>
# <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=431734abb8c23b754a7a297580b0fa43" type="text/javascript" ></script>
#   <script src="//www.craigslist.org/js/tocs-concat.min.js?v=0f57d11a76a5069301d6356de9e3f43d" type="text/javascript" ></script>
# </body>
# </html>

# %% [markdown]
# Wow, that's a lot of code. Remember, websites serve HTML documents, and usually your browser will automatically render this into a nice webpage for you. Since we're doing this with python, we get back the raw text. This is really useful, but how can we possibly parse it all?
#
# For this, we'll turn to another great package, BeautifulSoup:

# %%
from bs4 import BeautifulSoup as bs4

# BS4 can quickly parse our text, make sure to tell it that you're giving html
html = bs4(rsp.text, 'html.parser')

# BS makes it easy to look through a document
print(html.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <title>
#    SF bay area apartments / housing rentals  - craigslist
#   </title>
#   <meta content="SF bay area apartments / housing rentals  - craigslist" name="description">
#    <link href="https://sfbay.craigslist.org/search/eby/apa" rel="canonical">
#     <link href="https://sfbay.craigslist.org/search/eby/apa?bedrooms=1&amp;is_furnished=1&amp;format=rss" rel="alternate" title="RSS feed for craigslist | SF bay area apartments / housing rentals  - craigslist " type="application/rss+xml">
#      <meta content="initial-scale=1.0, user-scalable=1" name="viewport">
#       <link href="//www.craigslist.org/styles/cl.css?v=a593a03f11256e897b1b6294bfc3cbef" media="all" rel="stylesheet" type="text/css">
#        <link href="//www.craigslist.org/styles/tocs.css?v=d89a7dd9d708acf29a54986eb8b11bda" media="all" rel="stylesheet" type="text/css">
#         <link href="//www.craigslist.org/styles/jquery-ui-1.9.2.custom.css?v=86db72e37d2cf63cab3c63485c71becb" media="all" rel="stylesheet" type="text/css">
#          <link href="//www.craigslist.org/js/postings-concat.min.js?v=2c267741ac82581ef0aff79d8144768b" rel="prefetch">
#           <link href="//www.craigslist.org/styles/leaflet-stock.css?v=969bf0c010aad78a472cb96ed5c1d1bc" media="all" rel="stylesheet" type="text/css">
#            <link href="//www.craigslist.org/styles/MarkerCluster.css?v=c9937ed03fbb57f185493cd8c283efeb" media="all" rel="stylesheet" type="text/css">
#             <link href="//www.craigslist.org/styles/tocsmaps.css?v=0713fba1eea156d1e29815594450b352" media="all" rel="stylesheet" type="text/css">
#              <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">
# <![endif]-->
#              <script type="text/javascript">
#               <!--
#             var expiredFavIDs = [];
# var subarea = "eby";
# var maxResults = 2500;
# var lessInfoText = "less info";
# var showMapTabs = 1;
# var areaID = "1";
# var starHint = "save this post in your favorites list";
# var sectionAbb = "hhh";
# var catAbb = "apa";
# var currencySymbol = "&#x0024;";
# var areaRegion = "CA";
# var noImageText = "no image";
# var sectionBase = "hhh";
# var showInfoText = "show info";
# var zoomToPosting = null;
# var imageHost = "http://images.craigslist.org";
# var areaCountry = "US";
# var countOfTotalText = "image {count} of {total}";
# var pID = null;
#
#         -->
#              </script>
#              <!--[if lt IE 9]>
# <script src="//www.craigslist.org/js/html5shiv.min.js?v=096822b653643ed1af3136947e4ea79a" type="text/javascript" ></script>
# <![endif]-->
#              <!--[if lte IE 7]>
# <script src="//www.craigslist.org/js/json2.min.js?v=178d4ad319e0e0b4a451b15e49b71bec" type="text/javascript" ></script>
# <![endif]-->
#             </link>
#            </link>
#           </link>
#          </link>
#         </link>
#        </link>
#       </link>
#      </meta>
#     </link>
#    </link>
#   </meta>
#  </head>
#  <body class="toc search">
#   <script type="text/javascript">
#    <!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         var lng = C('cl_def_lang');
#         if (lng) bodyClassList.push(lng);
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof sectionAbb !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(sectionAbb + ':([^,]+)', 'i')) || {})[1];
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# -->
#   </script>
#   <section id="pagecontainer">
#    <div class="bglogo">
#    </div>
#    <header class="bchead mobile-header">
#     <div class="mobile-menu-button">
#      menu
#     </div>
#     <h2 class="mobile-logo">
#      <a class="mobile-logo-link" href="/">
#       craigslist
#      </a>
#      &gt; housing
#     </h2>
#    </header>
#    <nav class="breadcrumbs-container closed bchead">
#     <form action="/search/eby/apa" data-action="/search/###/apa" id="breadcrumbform" method="get">
#      <input name="is_furnished" type="hidden" value="1">
#       <input name="bedrooms" type="hidden" value="1">
#        <div class="breadbox">
#         <ul class="userlinks">
#          <li class="user post">
#           <a class="no-mobile" href="https://post.craigslist.org/c/sfo?lang=en">
#            post
#           </a>
#           <a class="mobile-only" href="https://post.craigslist.org/c/sfo?lang=en">
#            post to classifieds
#           </a>
#          </li>
#          <li class="user account">
#           <em>
#            [
#           </em>
#           <a class="no-mobile" href="https://accounts.craigslist.org/login/home">
#            account
#           </a>
#           <a class="mobile-only" href="https://accounts.craigslist.org/login/home">
#            my account
#           </a>
#           <em>
#            ]
#           </em>
#          </li>
#          <li class="user fav">
#           <div class="favorites">
#            <a class="favlink" href="#">
#             <span class="n">
#              0
#             </span>
#             <span class="no-mobile">
#              favorites
#             </span>
#            </a>
#           </div>
#          </li>
#         </ul>
#         <ul class="breadcrumbs">
#          <li class="crumb cl">
#           <a href="/">
#            CL
#           </a>
#          </li>
#          <li class="crumb area">
#           <label class="mobile-only submenu-text" for="areaAbb">
#            area
#           </label>
#           <span class="no-js">
#            <a href="/">
#             SF bay area
#            </a>
#           </span>
#           <select class="js-only" id="areaAbb" name="areaAbb">
#            <option value="sfbay">
#             SF bay area
#            </option>
#            <option value="bakersfield">
#             bakersfield
#            </option>
#            <option value="chico">
#             chico
#            </option>
#            <option value="fresno">
#             fresno
#            </option>
#            <option value="goldcountry">
#             gold country
#            </option>
#            <option value="hanford">
#             hanford
#            </option>
#            <option value="mendocino">
#             mendocino co
#            </option>
#            <option value="merced">
#             merced
#            </option>
#            <option value="modesto">
#             modesto
#            </option>
#            <option value="monterey">
#             monterey
#            </option>
#            <option value="redding">
#             redding
#            </option>
#            <option value="reno">
#             reno
#            </option>
#            <option value="sacramento">
#             sacramento
#            </option>
#            <option value="slo">
#             san luis obispo
#            </option>
#            <option value="santamaria">
#             santa maria
#            </option>
#            <option value="stockton">
#             stockton
#            </option>
#            <option value="susanville">
#             susanville
#            </option>
#            <option value="visalia">
#             visalia-tulare
#            </option>
#            <option value="yubasutter">
#             yuba-sutter
#            </option>
#           </select>
#           <span class="breadcrumb-arrow">
#            &gt;
#           </span>
#          </li>
#          <li class="crumb subarea">
#           <label class="mobile-only submenu-text" for="subArea">
#            subarea
#           </label>
#           <select id="subArea" name="subArea">
#            <option value="">
#             all SF bay area
#            </option>
#            <option selected="" value="eby">
#             east bay
#            </option>
#            <option value="nby">
#             north bay
#            </option>
#            <option value="pen">
#             peninsula
#            </option>
#            <option value="sfc">
#             san francisco
#            </option>
#            <option value="scz">
#             santa cruz
#            </option>
#            <option value="sby">
#             south bay
#            </option>
#           </select>
#           <span class="breadcrumb-arrow">
#            &gt;
#           </span>
#          </li>
#          <li class="crumb section">
#           <label class="mobile-only submenu-text" for="catAbb">
#            section
#           </label>
#           <select id="catAbb" name="catAbb">
#            <option value="ccc">
#             community
#            </option>
#            <option value="eee">
#             events
#            </option>
#            <option value="sss">
#             for sale
#            </option>
#            <option value="ggg">
#             gigs
#            </option>
#            <option selected="" value="hhh">
#             housing
#            </option>
#            <option value="jjj">
#             jobs
#            </option>
#            <option value="ppp">
#             personals
#            </option>
#            <option value="rrr">
#             resumes
#            </option>
#            <option value="bbb">
#             services
#            </option>
#           </select>
#           <span class="breadcrumb-arrow">
#            &gt;
#           </span>
#          </li>
#          <li class="crumb category">
#           <div class="mobile-only breadcrumb-labels">
#            category
#           </div>
#           <select class="js-only" id="subcatAbb">
#            <option value="hhh">
#             all
#            </option>
#            <option selected="" value="apa">
#             apts/housing for rent
#            </option>
#            <option value="hou">
#             apts wanted
#            </option>
#            <option value="swp">
#             housing swap
#            </option>
#            <option value="off">
#             office &amp; commercial
#            </option>
#            <option value="prk">
#             parking &amp; storage
#            </option>
#            <option value="reb">
#             real estate - by broker
#            </option>
#            <option value="reo">
#             real estate - by owner
#            </option>
#            <option value="rew">
#             real estate wanted
#            </option>
#            <option value="roo">
#             rooms &amp; shares
#            </option>
#            <option value="sha">
#             rooms wanted
#            </option>
#            <option value="sub">
#             sublets &amp; temporary
#            </option>
#            <option value="sbw">
#             sublet/temp wanted
#            </option>
#            <option value="vac">
#             vacation rentals
#            </option>
#           </select>
#           <span class="no-js">
#            apts/housing for rent
#           </span>
#           <span class="no-js">
#            <input type="submit" value="go"/>
#           </span>
#          </li>
#         </ul>
#        </div>
#        <div class="clearfix">
#        </div>
#       </input>
#      </input>
#     </form>
#    </nav>
#    <div class="middle">
#     <form action="/search/eby/apa" id="searchform">
#      <div class="searchbox">
#       <input id="excats" name="excats" type="hidden">
#        <div class="searchgroup showoptions linklike closed">
#         <span class="open">
#          –
#         </span>
#         <span class="closed">
#          +
#         </span>
#         categories &amp; options
#         <div class="mobile-favorites mobile-only">
#          <div class="favorites">
#           <a class="favlink" href="#">
#            <span class="n">
#             0
#            </span>
#            <span class="no-mobile">
#             favorites
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="searchoptions closed">
#         <script type="text/javascript">
#          <!--
#             var odaCats = {};
#
#         -->
#         </script>
#         <div class="searchgroup categories">
#          <div class="cattitle">
#           <a class="reset" href="/search/eby/apa" title="clear all search parameters">
#            apartments / housing rentals
#           </a>
#          </div>
#         </div>
#         <input id="is_paid" name="is_paid" type="hidden" value="">
#          <div class="searchgroup">
#           <ul>
#            <li>
#             <label class="srchType">
#              <input class="autosubmit" name="srchType" type="checkbox" value="T">
#               search titles only
#              </input>
#             </label>
#            </li>
#            <li>
#             <label class="hasPic">
#              <input class="autosubmit" name="hasPic" type="checkbox" value="1">
#               has image
#              </input>
#             </label>
#            </li>
#            <li>
#             <label class="postedToday">
#              <input class="autosubmit" name="postedToday" type="checkbox" value="1">
#               posted today
#              </input>
#             </label>
#            </li>
#           </ul>
#           <ul class="js-only nearbyAreas ">
#           </ul>
#          </div>
#          <div class="searchgroup">
#           <div class="catfilter attr_picker multilink " data-attr="nh" data-checked-count="0" id="headerattr_nh">
#            <span class="plusminus" id="plusminus_nh">
#             +
#            </span>
#            neighborhoods
#           </div>
#           <ul class="attr_list hideme" id="ul_nh">
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="alameda_46" name="nh" type="checkbox" value="46">
#               alameda
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="albany_/_el_cerrito_47" name="nh" type="checkbox" value="47">
#               albany / el cerrito
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="berkeley_48" name="nh" type="checkbox" value="48">
#               berkeley
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="berkeley_north_/_hills_49" name="nh" type="checkbox" value="49">
#               berkeley north / hills
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="brentwood_/_oakley_142" name="nh" type="checkbox" value="142">
#               brentwood / oakley
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="concord_/_pleasant_hill_/_martinez_51" name="nh" type="checkbox" value="51">
#               concord / pleasant hill / martinez
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="danville_/_san_ramon_52" name="nh" type="checkbox" value="52">
#               danville / san ramon
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="dublin_/_pleasanton_/_livermore_53" name="nh" type="checkbox" value="53">
#               dublin / pleasanton / livermore
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="emeryville_112" name="nh" type="checkbox" value="112">
#               emeryville
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="fairfield_/_vacaville_154" name="nh" type="checkbox" value="154">
#               fairfield / vacaville
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="fremont_/_union_city_/_newark_54" name="nh" type="checkbox" value="54">
#               fremont / union city / newark
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="hayward_/_castro_valley_55" name="nh" type="checkbox" value="55">
#               hayward / castro valley
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="hercules,_pinole,_san_pablo,_el_sob_56" name="nh" type="checkbox" value="56">
#               hercules, pinole, san pablo, el sob
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="lafayette_/_orinda_/_moraga_57" name="nh" type="checkbox" value="57">
#               lafayette / orinda / moraga
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="oakland_downtown_58" name="nh" type="checkbox" value="58">
#               oakland downtown
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="oakland_east_59" name="nh" type="checkbox" value="59">
#               oakland east
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="oakland_hills_/_mills_60" name="nh" type="checkbox" value="60">
#               oakland hills / mills
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="oakland_lake_merritt_/_grand_61" name="nh" type="checkbox" value="61">
#               oakland lake merritt / grand
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="oakland_north_/_temescal_62" name="nh" type="checkbox" value="62">
#               oakland north / temescal
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="oakland_piedmont_/_montclair_63" name="nh" type="checkbox" value="63">
#               oakland piedmont / montclair
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="oakland_rockridge_/_claremont_66" name="nh" type="checkbox" value="66">
#               oakland rockridge / claremont
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="oakland_west_64" name="nh" type="checkbox" value="64">
#               oakland west
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="pittsburg_/_antioch_113" name="nh" type="checkbox" value="113">
#               pittsburg / antioch
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="richmond_/_point_/_annex_65" name="nh" type="checkbox" value="65">
#               richmond / point / annex
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="san_leandro_67" name="nh" type="checkbox" value="67">
#               san leandro
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="vallejo_/_benicia_68" name="nh" type="checkbox" value="68">
#               vallejo / benicia
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="walnut_creek_69" name="nh" type="checkbox" value="69">
#               walnut creek
#              </input>
#             </label>
#            </li>
#            <li class="selectall js-only attr_nh ">
#             <label>
#              <input class="selectallcb multi_checkbox" data-attr="nh" type="checkbox">
#               <span class="all select_all_nh">
#                select all
#               </span>
#               <span class="none deselect_all_nh">
#                deselect all
#               </span>
#              </input>
#             </label>
#            </li>
#           </ul>
#          </div>
#          <div class="searchgroup minmax ">
#           <span class="searchfieldlabel">
#            price
#           </span>
#           <input class="flatinput min" name="min_price" placeholder="min" title="whole number, no letters or symbols" type="tel" value="">
#            <input class="flatinput max" name="max_price" placeholder="max" title="whole number, no letters or symbols" type="tel" value="">
#            </input>
#           </input>
#          </div>
#          <div class="searchgroup">
#           <select class="autosubmit" name="bedrooms">
#            <option value="">
#             all bedrooms
#            </option>
#            <option selected="selected" value="1">
#             1+ bedrooms
#            </option>
#            <option value="2">
#             2+ bedrooms
#            </option>
#            <option value="3">
#             3+ bedrooms
#            </option>
#            <option value="4">
#             4+ bedrooms
#            </option>
#            <option value="5">
#             5+ bedrooms
#            </option>
#            <option value="6">
#             6+ bedrooms
#            </option>
#            <option value="7">
#             7+ bedrooms
#            </option>
#            <option value="8">
#             8+ bedrooms
#            </option>
#           </select>
#           <br>
#            <select class="autosubmit" name="bathrooms">
#             <option value="">
#              all bathrooms
#             </option>
#             <option value="1">
#              1+ bathrooms
#             </option>
#             <option value="2">
#              2+ bathrooms
#             </option>
#             <option value="3">
#              3+ bathrooms
#             </option>
#             <option value="4">
#              4+ bathrooms
#             </option>
#             <option value="5">
#              5+ bathrooms
#             </option>
#             <option value="6">
#              6+ bathrooms
#             </option>
#             <option value="7">
#              7+ bathrooms
#             </option>
#             <option value="8">
#              8+ bathrooms
#             </option>
#            </select>
#           </br>
#          </div>
#          <div class="searchgroup minmax ">
#           <span class="searchfieldlabel">
#            ft
#            <sup>
#             2
#            </sup>
#           </span>
#           <input class="flatinput min" name="minSqft" placeholder="min" title="whole number, no letters or symbols" type="tel" value="">
#            <input class="flatinput max" name="maxSqft" placeholder="max" title="whole number, no letters or symbols" type="tel" value="">
#            </input>
#           </input>
#          </div>
#          <div class="searchgroup">
#           <label class="pets_cat">
#            <input class="autosubmit" name="pets_cat" type="checkbox" value="1">
#             cats ok
#            </input>
#           </label>
#           <br>
#            <label class="pets_dog">
#             <input class="autosubmit" name="pets_dog" type="checkbox" value="1">
#              dogs ok
#             </input>
#            </label>
#            <br>
#             <label class="is_furnished">
#              <input checked="checked" class="autosubmit" name="is_furnished" type="checkbox" value="1">
#               furnished
#              </input>
#             </label>
#             <br>
#              <label class="no_smoking">
#               <input class="autosubmit" name="no_smoking" type="checkbox" value="1">
#                no smoking
#               </input>
#              </label>
#              <br>
#               <label class="wheelchaccess">
#                <input class="autosubmit" name="wheelchaccess" type="checkbox" value="1">
#                 wheelchair access
#                </input>
#               </label>
#               <br/>
#              </br>
#             </br>
#            </br>
#           </br>
#          </div>
#          <div class="searchgroup">
#           <div class="catfilter attr_picker multilink " data-attr="housing_type" data-checked-count="0" id="headerattr_housing_type">
#            <span class="plusminus" id="plusminus_housing_type">
#             +
#            </span>
#            housing type
#           </div>
#           <ul class="attr_list hideme" id="ul_housing_type">
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="apartment_1" name="housing_type" type="checkbox" value="1">
#               apartment
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="condo_2" name="housing_type" type="checkbox" value="2">
#               condo
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="cottage/cabin_3" name="housing_type" type="checkbox" value="3">
#               cottage/cabin
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="duplex_4" name="housing_type" type="checkbox" value="4">
#               duplex
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="flat_5" name="housing_type" type="checkbox" value="5">
#               flat
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="house_6" name="housing_type" type="checkbox" value="6">
#               house
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="in-law_7" name="housing_type" type="checkbox" value="7">
#               in-law
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="loft_8" name="housing_type" type="checkbox" value="8">
#               loft
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="townhouse_9" name="housing_type" type="checkbox" value="9">
#               townhouse
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="manufactured_10" name="housing_type" type="checkbox" value="10">
#               manufactured
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="assisted_living_11" name="housing_type" type="checkbox" value="11">
#               assisted living
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="land_12" name="housing_type" type="checkbox" value="12">
#               land
#              </input>
#             </label>
#            </li>
#            <li class="selectall js-only attr_housing_type ">
#             <label>
#              <input class="selectallcb multi_checkbox" data-attr="housing_type" type="checkbox">
#               <span class="all select_all_housing_type">
#                select all
#               </span>
#               <span class="none deselect_all_housing_type">
#                deselect all
#               </span>
#              </input>
#             </label>
#            </li>
#           </ul>
#           <div class="catfilter attr_picker multilink " data-attr="laundry" data-checked-count="0" id="headerattr_laundry">
#            <span class="plusminus" id="plusminus_laundry">
#             +
#            </span>
#            laundry
#           </div>
#           <ul class="attr_list hideme" id="ul_laundry">
#            <li class="attr_laundry ">
#             <label data-attr="laundry">
#              <input class="multi_checkbox multi_laundry" data-attr="laundry" id="w/d_in_unit_1" name="laundry" type="checkbox" value="1">
#               w/d in unit
#              </input>
#             </label>
#            </li>
#            <li class="attr_laundry ">
#             <label data-attr="laundry">
#              <input class="multi_checkbox multi_laundry" data-attr="laundry" id="w/d_hookups_4" name="laundry" type="checkbox" value="4">
#               w/d hookups
#              </input>
#             </label>
#            </li>
#            <li class="attr_laundry ">
#             <label data-attr="laundry">
#              <input class="multi_checkbox multi_laundry" data-attr="laundry" id="laundry_in_bldg_2" name="laundry" type="checkbox" value="2">
#               laundry in bldg
#              </input>
#             </label>
#            </li>
#            <li class="attr_laundry ">
#             <label data-attr="laundry">
#              <input class="multi_checkbox multi_laundry" data-attr="laundry" id="laundry_on_site_3" name="laundry" type="checkbox" value="3">
#               laundry on site
#              </input>
#             </label>
#            </li>
#            <li class="attr_laundry ">
#             <label data-attr="laundry">
#              <input class="multi_checkbox multi_laundry" data-attr="laundry" id="no_laundry_on_site_5" name="laundry" type="checkbox" value="5">
#               no laundry on site
#              </input>
#             </label>
#            </li>
#           </ul>
#           <div class="catfilter attr_picker multilink " data-attr="parking" data-checked-count="0" id="headerattr_parking">
#            <span class="plusminus" id="plusminus_parking">
#             +
#            </span>
#            parking
#           </div>
#           <ul class="attr_list hideme" id="ul_parking">
#            <li class="attr_parking ">
#             <label data-attr="parking">
#              <input class="multi_checkbox multi_parking" data-attr="parking" id="carport_1" name="parking" type="checkbox" value="1">
#               carport
#              </input>
#             </label>
#            </li>
#            <li class="attr_parking ">
#             <label data-attr="parking">
#              <input class="multi_checkbox multi_parking" data-attr="parking" id="attached_garage_2" name="parking" type="checkbox" value="2">
#               attached garage
#              </input>
#             </label>
#            </li>
#            <li class="attr_parking ">
#             <label data-attr="parking">
#              <input class="multi_checkbox multi_parking" data-attr="parking" id="detached_garage_3" name="parking" type="checkbox" value="3">
#               detached garage
#              </input>
#             </label>
#            </li>
#            <li class="attr_parking ">
#             <label data-attr="parking">
#              <input class="multi_checkbox multi_parking" data-attr="parking" id="off-street_parking_4" name="parking" type="checkbox" value="4">
#               off-street parking
#              </input>
#             </label>
#            </li>
#            <li class="attr_parking ">
#             <label data-attr="parking">
#              <input class="multi_checkbox multi_parking" data-attr="parking" id="street_parking_5" name="parking" type="checkbox" value="5">
#               street parking
#              </input>
#             </label>
#            </li>
#            <li class="attr_parking ">
#             <label data-attr="parking">
#              <input class="multi_checkbox multi_parking" data-attr="parking" id="valet_parking_6" name="parking" type="checkbox" value="6">
#               valet parking
#              </input>
#             </label>
#            </li>
#            <li class="attr_parking ">
#             <label data-attr="parking">
#              <input class="multi_checkbox multi_parking" data-attr="parking" id="no_parking_7" name="parking" type="checkbox" value="7">
#               no parking
#              </input>
#             </label>
#            </li>
#            <li class="selectall js-only attr_parking ">
#             <label>
#              <input class="selectallcb multi_checkbox" data-attr="parking" type="checkbox">
#               <span class="all select_all_parking">
#                select all
#               </span>
#               <span class="none deselect_all_parking">
#                deselect all
#               </span>
#              </input>
#             </label>
#            </li>
#           </ul>
#          </div>
#          <div class="searchgroup">
#           <div class="label">
#            open house date
#           </div>
#           <select class="autosubmit" id="sale_date" name="sale_date">
#            <option>
#            </option>
#            <option value="2015-08-21">
#             aug 21 - today
#            </option>
#            <option value="2015-08-22">
#             aug 22 - tomorrow
#            </option>
#            <option value="2015-08-23">
#             aug 23 - sunday
#            </option>
#            <option value="2015-08-24">
#             aug 24 - monday
#            </option>
#            <option value="2015-08-25">
#             aug 25 - tuesday
#            </option>
#            <option value="2015-08-26">
#             aug 26 - wednesday
#            </option>
#            <option value="2015-08-27">
#             aug 27 - thursday
#            </option>
#            <option value="2015-08-28">
#             aug 28 - friday
#            </option>
#            <option value="2015-08-29">
#             aug 29 - saturday
#            </option>
#            <option value="2015-08-30">
#             aug 30 - sunday
#            </option>
#            <option value="2015-08-31">
#             aug 31 - monday
#            </option>
#            <option value="2015-09-01">
#             sep 1 - tuesday
#            </option>
#            <option value="2015-09-02">
#             sep 2 - wednesday
#            </option>
#            <option value="2015-09-03">
#             sep 3 - thursday
#            </option>
#           </select>
#          </div>
#          <div class="searchgroup resetsearch">
#           <a class="reset linklike" href="/search/eby/apa" title="clear all search parameters">
#            reset
#           </a>
#           <button class="searchlink linklike" type="submit">
#            search
#           </button>
#          </div>
#         </input>
#        </div>
#        <div class="no-mobile">
#        </div>
#       </input>
#      </div>
#      <div class="rightpane">
#       <div class="querybox">
#        <span class="form-tab js-only">
#         <span class="search-open" title="hide search">
#          «
#         </span>
#         <span class="search-closed" title="show search">
#          »
#         </span>
#        </span>
#        <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search apartments / housing rentals" type="text" value="">
#         <button class="searchbtn" type="submit">
#          <span class="searchicon">
#          </span>
#         </button>
#         <div class="savealert">
#          <a class="saveme no-mobile" data-action="alert" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Falert%3FURL%3Dhttps%253A%252F%252Fsfbay%252Ecraigslist%252Eorg%252Fsearch%252Feby%252Fapa%253Fbedrooms%253D1%2526is%255Ffurnished%253D1" title="save this search with email alerts ">
#           email alert
#          </a>
#          <a class="saveme no-mobile" data-action="save" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Fsfbay%252Ecraigslist%252Eorg%252Fsearch%252Feby%252Fapa%253Fbedrooms%253D1%2526is%255Ffurnished%253D1" title="save this search ">
#           save search
#          </a>
#          <a class="saveme mobile-only" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Falert%3FURL%3Dhttps%253A%252F%252Fsfbay%252Ecraigslist%252Eorg%252Fsearch%252Feby%252Fapa%253Fbedrooms%253D1%2526is%255Ffurnished%253D1">
#           search alert
#          </a>
#         </div>
#        </input>
#       </div>
#       <div class="toc_legend">
#        <div class="center">
#         <div class="tocview">
#          <span class="buttongroup js-only">
#           <a class="mode button" data-view="list" href="#list" id="listview" title="show results in a list">
#            list
#           </a>
#           <a class="mode button" data-view="pic" href="#pic" id="picview" title="show results in a list with thumbnail pictures">
#            thumb
#           </a>
#           <a class="mode button" data-view="grid" href="#grid" id="gridview" title="show results side-by-side with larger pictures">
#            gallery
#           </a>
#           <a class="mode button" data-view="map" href="#map" id="mapview" title="show results on a map">
#            map
#           </a>
#          </span>
#         </div>
#         <div class="tocsort">
#          <span class="buttongroup">
#           <span class="button sel">
#            newest
#           </span>
#           <a class="button" href="/search/eby/apa?sort=priceasc&amp;bedrooms=1&amp;is_furnished=1" title="sort by price, lowest to highest">
#            <span class="pricesort">
#             <span class="pricesort">
#              $
#             </span>
#             $
#            </span>
#            $
#           </a>
#           <a class="button" href="/search/eby/apa?sort=pricedsc&amp;bedrooms=1&amp;is_furnished=1" title="sort by price, highest to lowest">
#            $
#            <span class="pricesort">
#             $
#             <span class="pricesort">
#              $
#             </span>
#            </span>
#           </a>
#          </span>
#         </div>
#         <span class="paginator buttongroup firstpage lastpage">
#          <span class="resulttotal">
#           displaying
#           <span class="displaycount">
#            ...
#           </span>
#           <span class="of-total">
#            of
#            <span class="totalcount">
#             84
#            </span>
#           </span>
#           postings
#          </span>
#          <span class="buttons">
#           <a class="button first" href="/search/eby/apa?bedrooms=1&amp;is_furnished=1" title="first page">
#            &lt;&lt;
#           </a>
#           <span class="button first" title="first page">
#            &lt;&lt;
#           </span>
#           <a class="button prev" href="/search/eby/apa?bedrooms=1&amp;is_furnished=1" title="previous page">
#            &lt; prev
#           </a>
#           <span class="button prev" title="previous page">
#            &lt; prev
#           </span>
#           <span class="button pagenum">
#            <span class="range">
#             <span class="rangeFrom">
#              1
#             </span>
#             to
#             <span class="rangeTo">
#              84
#             </span>
#            </span>
#            <span class="of-total">
#             of
#             <span class="totalcount">
#              84
#             </span>
#            </span>
#           </span>
#           <a class="button next" href="/search/eby/apa?s=84&amp;bedrooms=1&amp;is_furnished=1" title="next page">
#            next &gt;
#           </a>
#           <span class="button next" title="next page">
#            next &gt;
#           </span>
#          </span>
#         </span>
#        </div>
#       </div>
#       <div class="content">
#        <section class="favlistsection">
#         <section class="favlistinfo">
#         </section>
#        </section>
#        <p class="row" data-pid="5183961779">
#         <a class="i" data-ids="0:00f0f_4VOyuRKg1NL,0:00d0d_cPsrSIKZ65M,0:00101_49n5wQ2FpPz,0:00L0L_cdHq3zu3Vg5,0:00H0H_lGZouxLZlnS" href="/eby/apa/5183961779.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-08-21 12:13" title="Fri 21 Aug 12:13:51 PM">
#            Aug 21
#           </time>
#           <a class="hdrlnk" data-id="5183961779" href="/eby/apa/5183961779.html">
#            North Berkeley Furnished In-Law
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $990
#           </span>
#           <span class="housing">
#            / 1br -
#           </span>
#           <span class="pnr">
#            <small>
#             (berkeley north / hills)
#            </small>
#            <span class="px">
#             <span class="p">
#              pic
#              <span class="maptag" data-pid="5183961779">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5183961779" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5183961779" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5183952420" data-repost-of="3041402814">
#         <a class="i" href="/eby/apa/5183952420.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-08-21 12:08" title="Fri 21 Aug 12:08:58 PM">
#            Aug 21
#           </time>
#           <a class="hdrlnk" data-id="5183952420" href="/eby/apa/5183952420.html">
#            Sunny Townhouse unit on quiet street can be furnished
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $2300
#           </span>
#           <span class="housing">
#            / 2br - 700ft
#            <sup>
#             2
#            </sup>
#            -
#           </span>
#           <span class="pnr">
#            <small>
#             (berkeley)
#            </small>
#            <span class="px">
#             <span class="p">
#              <span class="maptag" data-pid="5183952420">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5183952420" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5183952420" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5183881696">
#         <a class="i" data-ids="0:00r0r_cTxkpzEvod8,0:00o0o_a4xg37PaxFt,0:00s0s_4CNMAdBCluS,0:00G0G_kOol9aNIFQM,0:00C0C_1TscT7X7zYd,0:00d0d_lfUXtL9AwWG" href="/eby/apa/5183881696.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-08-21 11:29" title="Fri 21 Aug 11:29:57 AM">
#            Aug 21
#           </time>
#           <a class="hdrlnk" data-id="5183881696" href="/eby/apa/5183881696.html">
#            Modern 1br Condo Furnished Avail Sept 10 - Nov 10
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $2450
#           </span>
#           <span class="housing">
#            / 1br - 800ft
#            <sup>
#             2
#            </sup>
#            -
#           </span>
#           <span class="pnr">
#            <small>
#             (emeryville)
#            </small>
#            <span class="px">
#             <span class="p">
#              pic
#              <span class="maptag" data-pid="5183881696">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5183881696" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5183881696" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5183619662">
#         <a class="i" data-ids="0:00f0f_5AOqcodDiee" href="/eby/apa/5183619662.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-08-21 11:07" title="Fri 21 Aug 11:07:52 AM">
#            Aug 21
#           </time>
#           <a class="hdrlnk" data-id="5183619662" href="/eby/apa/5183619662.html">
#            Fantastic deal for this 3 bedrooms house
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $2415
#           </span>
#           <span class="housing">
#            / 3br - 1148ft
#            <sup>
#             2
#            </sup>
#            -
#           </span>
#           <span class="pnr">
#            <small>
#             (fremont / union city / newark)
#            </small>
#            <span class="px">
#             <span class="p">
#              pic
#              <span class="maptag" data-pid="5183619662">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
# ...
#           </span>
#           <span class="pnr">
#            <small>
#             <span class="nearby" title="SF bay area">
#              (sfo &gt; san jose downtown)
#             </span>
#            </small>
#            <span class="px">
#             <span class="p">
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5173780064" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5173780064" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5183442489">
#         <a class="i" href="//sacramento.craigslist.org/apa/5183442489.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-08-21 07:42" title="Fri 21 Aug 07:42:10 AM">
#            Aug 21
#           </time>
#           <a class="hdrlnk" data-id="5183442489" href="//sacramento.craigslist.org/apa/5183442489.html">
#            On Sabbatical - semi-furnished house available
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $1750
#           </span>
#           <span class="housing">
#            / 3br - 1200ft
#            <sup>
#             2
#            </sup>
#            -
#           </span>
#           <span class="pnr">
#            <small>
#             <span class="nearby" title="sacramento">
#              (sac &gt; Davis)
#             </span>
#            </small>
#            <span class="px">
#             <span class="p">
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5183442489" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5183442489" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5163688139" data-repost-of="5135874993">
#         <a class="i" data-ids="0:00i0i_cI0aj9cvCgr,0:00h0h_5r7tCRfNy41,0:00e0e_iXYK1MWTExD,0:00S0S_9NXwKHrROJE,0:00V0V_ixM1dL8DgwE,0:00b0b_jYb9awHzecl,0:00a0a_lL8cykdPacv,0:01717_6QX16OnSMP2,0:01717_barq6lNGzeR,0:00808_4uwlatjAeL1,0:00W0W_daCskJzr8xe,0:00C0C_3IgxetFsDRY,0:00606_fOr5o0pf7Cf,0:00M0M_4Yuqyf06nLQ,0:01313_adyKEZcO9sE,0:00606_4fuBSTCZb20,0:00l0l_eLj32PEW2S,0:01010_eAvHaoOPXZn,0:00y0y_fEQYOGnsWq6,0:00D0D_ItleaaafKC" href="//sfbay.craigslist.org/sby/apa/5163688139.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-08-21 07:40" title="Fri 21 Aug 07:40:11 AM">
#            Aug 21
#           </time>
#           <a class="hdrlnk" data-id="5163688139" href="//sfbay.craigslist.org/sby/apa/5163688139.html">
#            Westgate: Newly Remodeled Apt
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $4000
#           </span>
#           <span class="housing">
#            / 1br - 608ft
#            <sup>
#             2
#            </sup>
#            -
#           </span>
#           <span class="pnr">
#            <small>
#             <span class="nearby" title="SF bay area">
#              (sfo &gt; san jose west)
#             </span>
#            </small>
#            <span class="px">
#             <span class="p">
#              pic
#              <span class="maptag" data-pid="5163688139">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5163688139" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5163688139" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5148373355">
#         <a class="i" data-ids="0:00i0i_f46plPkxrlJ,0:01313_25S1t4RzFlp,0:00o0o_riZF6Yl2IC,0:00101_iZ5YXl937wp,0:00k0k_hHXZZSd6Snm,0:00404_bh8r0SiKVxR,0:00606_ek5HMO5gUSk" href="//sfbay.craigslist.org/pen/apa/5148373355.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-08-21 07:38" title="Fri 21 Aug 07:38:30 AM">
#            Aug 21
#           </time>
#           <a class="hdrlnk" data-id="5148373355" href="//sfbay.craigslist.org/pen/apa/5148373355.html">
#            Furnished Woodlake 1bd, FREE Utilities-Cable-Internet - Flex Lease - Oct 1
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $2999
#           </span>
#           <span class="housing">
#            / 1br - 693ft
#            <sup>
#             2
#            </sup>
#            -
#           </span>
#           <span class="pnr">
#            <small>
#             <span class="nearby" title="SF bay area">
#              (sfo &gt; san mateo)
#             </span>
#            </small>
#            <span class="px">
#             <span class="p">
#              pic
#              <span class="maptag" data-pid="5148373355">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5148373355" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5148373355" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5145702620">
#         <a class="i" data-ids="0:00n0n_cqYBHhFVZXe,0:00N0N_cozAdfCy43k,0:00B0B_l6FWVahi2DK,0:00Z0Z_cV9vP67hT7f,0:01313_jqFVKtJPRYO,0:00f0f_4ybf5DN8wkl,0:01616_1MvFLbCQPIA,0:01212_9d4iJERkaxU,0:00C0C_c595YrwwKyx,0:00z0z_1UrCxz3ZJ4I,0:00r0r_mkwxYCepe5,0:00A0A_l0a9ASXHd55,0:00v0v_67EazZTfhYN,0:00f0f_1AGqn6HpAPT,0:00x0x_f9RcYqKLBjI,0:00u0u_gEhDsL0C94Z,0:00p0p_d2dLQlFAqse" href="//sfbay.craigslist.org/sfc/apa/5145702620.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-08-21 07:09" title="Fri 21 Aug 07:09:15 AM">
#            Aug 21
#           </time>
#           <a class="hdrlnk" data-id="5145702620" href="//sfbay.craigslist.org/sfc/apa/5145702620.html">
#            Victorian Charm in Hayes Valley!! LOTS of Tech Buses; Easy City Commute
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $5980
#           </span>
#           <span class="housing">
#            / 3br -
#           </span>
#           <span class="pnr">
#            <small>
#             <span class="nearby" title="SF bay area">
#              (sfo &gt; hayes valley)
#             </span>
#            </small>
#            <span class="px">
#             <span class="p">
#              pic
#              <span class="maptag" data-pid="5145702620">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5145702620" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5145702620" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <div data-arealat="37.500000" data-arealon="-122.250000" id="mapcontainer">
#         <div id="noresult_overlay">
#         </div>
#         <div id="noresult_text">
#          <span class="message">
#           No mappable items found
#          </span>
#         </div>
#         <div class="loading" id="map">
#          <div class="closeFS">
#           ×
#          </div>
#         </div>
#        </div>
#        <div class="toc_legend bottom">
#         <div class="center">
#          <div class="tocview">
#           <span class="buttongroup">
#            <a class="backtotop button" href="#pagecontainer">
#             ^ back to top
#            </a>
#           </span>
#          </div>
#          <div class="tocsort">
#           <span class="buttongroup">
#            <a class="backtotop button" href="#pagecontainer">
#             ^ back to top
#            </a>
#           </span>
#          </div>
#          <span class="paginator buttongroup firstpage lastpage">
#           <span class="resulttotal">
#            displaying
#            <span class="displaycount">
#             ...
#            </span>
#            <span class="of-total">
#             of
#             <span class="totalcount">
#              84
#             </span>
#            </span>
#            postings
#           </span>
#           <span class="buttons">
#            <a class="button first" href="/search/eby/apa?bedrooms=1&amp;is_furnished=1" title="first page">
#             &lt;&lt;
#            </a>
#            <span class="button first" title="first page">
#             &lt;&lt;
#            </span>
#            <a class="button prev" href="/search/eby/apa?bedrooms=1&amp;is_furnished=1" title="previous page">
#             &lt; prev
#            </a>
#            <span class="button prev" title="previous page">
#             &lt; prev
#            </span>
#            <span class="button pagenum">
#             <span class="range">
#              <span class="rangeFrom">
#               1
#              </span>
#              to
#              <span class="rangeTo">
#               84
#              </span>
#             </span>
#             <span class="of-total">
#              of
#              <span class="totalcount">
#               84
#              </span>
#             </span>
#            </span>
#            <a class="button next" href="/search/eby/apa?s=84&amp;bedrooms=1&amp;is_furnished=1" title="next page">
#             next &gt;
#            </a>
#            <span class="button next" title="next page">
#             next &gt;
#            </span>
#           </span>
#          </span>
#         </div>
#        </div>
#       </div>
#      </div>
#      <section class="blurbs">
#      </section>
#      <div id="floater">
#       <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif">
#        <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif">
#        </img>
#       </img>
#      </div>
#      <template id="gallerycarousel">
#       <div class="sliderinfo">
#       </div>
#       <div class="sliderback arrow">
#        &lt;
#       </div>
#       <div class="sliderforward arrow">
#        &gt;
#       </div>
#      </template>
#     </form>
#    </div>
#    <div class="mobile-only">
#    </div>
#    <div class="discards footstool no-mobile js-only">
#     <p>
#      <strong class="hidden_count">
#      </strong>
#      hidden
#     </p>
#     <!-- show if there is at least one hidden thing and the hidden are NOT revealed -->
#     <div class="show-discards-link linklike" role="button" tabindex="0">
#      click to show
#     </div>
#     <!-- show if there is at least one hidden thing and the hidden ARE not revealed -->
#     <div class="hide-discards-link linklike" role="button" tabindex="0">
#      click to hide
#     </div>
#    </div>
#    <footer>
#     <span class="rss">
#      <a class="l" href="https://sfbay.craigslist.org/search/eby/apa?bedrooms=1&amp;is_furnished=1&amp;format=rss">
#       RSS
#      </a>
#      <a href="http://www.craigslist.org/about/rss">
#       (?)
#      </a>
#      <br>
#      </br>
#     </span>
#     <ul class="clfooter">
#      <li>
#       © 2015
#       <span class="desktop">
#        craigslist
#       </span>
#       <span class="mobile">
#        CL
#       </span>
#      </li>
#      <li>
#       <a href="//www.craigslist.org/about/help/">
#        help
#       </a>
#      </li>
#      <li>
#       <a href="//www.craigslist.org/about/scams">
#        safety
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="//www.craigslist.org/about/privacy.policy">
#        privacy
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://forums.craigslist.org/?forumID=8">
#        feedback
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="//www.craigslist.org/about/craigslist_is_hiring">
#        cl jobs
#       </a>
#      </li>
#      <li>
#       <a href="//www.craigslist.org/about/terms.of.use">
#        terms
#       </a>
#      </li>
#      <li>
#       <a href="//www.craigslist.org/about/">
#        about
#       </a>
#      </li>
#      <li class="fsel desktop linklike" data-mode="mobile">
#       mobile
#      </li>
#      <li class="fsel mobile linklike" data-mode="regular">
#       desktop
#      </li>
#     </ul>
#    </footer>
#   </section>
#   <script src="//www.craigslist.org/js/general-concat.min.js?v=7db13e14edce1be55946b402b4ae2132" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--
#         var iframe = document.createElement('iframe');
#         iframe.style.display = 'none';
#         iframe.src = '//www.' + CL.url.baseDomain + '/static/localstorage.html?v=51a29e41f8e978141e4085ed4a77d170';
#         document.body.insertBefore(iframe, null);
#     -->
#   </script>
#   <script id="clustertemplate" type="text/template">
#    <li class="posting {visited}" data-id="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#          <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#          <span class="bedrooms">{BedroomsContent}</span>
#          <span class="postingtitle"><a>{PostingTitle}</a></span>
#          <span class="js-only map-banish-unbanish no-mobile" data-pid="{PostingID}">
#           [<a class="banish" id="banisher" data-pid="{PostingID}" title="hide">x</a><a class="unbanish" id="unbanisher" data-pid="{PostingID}" title="unhide">undo</a>]
#          </span>
#         </div>
#     </li>
#   </script>
#   <script id="postingtemplate" type="text/template">
#    <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             <button class="back" type="button">&lt;</button> back to posting list
#         </div>
#         <div class="title">
#             <span class="star" data-pid="{PostingID}"></span>
#             <span class="postingtitle">
#               <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish no-mobile single">
#                   [<a class="banish" id="banisher" data-pid="{PostingID}" title="hide">x</a><a class="unbanish" id="unbanisher" data-pid="{PostingID}" title="unhide">undo</a>]
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer">
#             <div class="slidernav">
#                 <span class="sliderback">&lt;</span><span class="sliderinfo"></span><span class="sliderforward">&gt;</span>
#             </div>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <abbr class="date timeago" title="{isoPostedDate}">{humanPostedDate}</abbr>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
#   </script>
#   <script id="popuptemplate" type="text/template">
#    <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
#   </script>
#   <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=431734abb8c23b754a7a297580b0fa43" type="text/javascript">
#   </script>
#   <script src="//www.craigslist.org/js/tocs-concat.min.js?v=0f57d11a76a5069301d6356de9e3f43d" type="text/javascript">
#   </script>
#  </body>
# </html>

# %% [markdown]
# Beautiful soup lets us quickly search through an HTML document. We can pull out whatever information we want.
#
# Scanning through this text, we see a common structure repeated `<p class="row">`. This seems to be the container that has information for a single apartment.
#
# In BeautifulSoup, we can quickly get all instances of this container:

# %%
print(html.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <title>
#    SF bay area apartments / housing rentals  - craigslist
#   </title>
#   <meta content="SF bay area apartments / housing rentals  - craigslist" name="description">
#    <link href="https://sfbay.craigslist.org/search/eby/apa" rel="canonical">
#     <link href="https://sfbay.craigslist.org/search/eby/apa?bedrooms=1&amp;is_furnished=1&amp;format=rss" rel="alternate" title="RSS feed for craigslist | SF bay area apartments / housing rentals  - craigslist " type="application/rss+xml">
#      <meta content="initial-scale=1.0, user-scalable=1" name="viewport">
#       <link href="//www.craigslist.org/styles/cl.css?v=a593a03f11256e897b1b6294bfc3cbef" media="all" rel="stylesheet" type="text/css">
#        <link href="//www.craigslist.org/styles/tocs.css?v=d89a7dd9d708acf29a54986eb8b11bda" media="all" rel="stylesheet" type="text/css">
#         <link href="//www.craigslist.org/styles/jquery-ui-1.9.2.custom.css?v=86db72e37d2cf63cab3c63485c71becb" media="all" rel="stylesheet" type="text/css">
#          <link href="//www.craigslist.org/js/postings-concat.min.js?v=2c267741ac82581ef0aff79d8144768b" rel="prefetch">
#           <link href="//www.craigslist.org/styles/leaflet-stock.css?v=969bf0c010aad78a472cb96ed5c1d1bc" media="all" rel="stylesheet" type="text/css">
#            <link href="//www.craigslist.org/styles/MarkerCluster.css?v=c9937ed03fbb57f185493cd8c283efeb" media="all" rel="stylesheet" type="text/css">
#             <link href="//www.craigslist.org/styles/tocsmaps.css?v=0713fba1eea156d1e29815594450b352" media="all" rel="stylesheet" type="text/css">
#              <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">
# <![endif]-->
#              <script type="text/javascript">
#               <!--
#             var expiredFavIDs = [];
# var subarea = "eby";
# var maxResults = 2500;
# var lessInfoText = "less info";
# var showMapTabs = 1;
# var areaID = "1";
# var starHint = "save this post in your favorites list";
# var sectionAbb = "hhh";
# var catAbb = "apa";
# var currencySymbol = "&#x0024;";
# var areaRegion = "CA";
# var noImageText = "no image";
# var sectionBase = "hhh";
# var showInfoText = "show info";
# var zoomToPosting = null;
# var imageHost = "http://images.craigslist.org";
# var areaCountry = "US";
# var countOfTotalText = "image {count} of {total}";
# var pID = null;
#
#         -->
#              </script>
#              <!--[if lt IE 9]>
# <script src="//www.craigslist.org/js/html5shiv.min.js?v=096822b653643ed1af3136947e4ea79a" type="text/javascript" ></script>
# <![endif]-->
#              <!--[if lte IE 7]>
# <script src="//www.craigslist.org/js/json2.min.js?v=178d4ad319e0e0b4a451b15e49b71bec" type="text/javascript" ></script>
# <![endif]-->
#             </link>
#            </link>
#           </link>
#          </link>
#         </link>
#        </link>
#       </link>
#      </meta>
#     </link>
#    </link>
#   </meta>
#  </head>
#  <body class="toc search">
#   <script type="text/javascript">
#    <!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         var lng = C('cl_def_lang');
#         if (lng) bodyClassList.push(lng);
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof sectionAbb !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(sectionAbb + ':([^,]+)', 'i')) || {})[1];
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# -->
#   </script>
#   <section id="pagecontainer">
#    <div class="bglogo">
#    </div>
#    <header class="bchead mobile-header">
#     <div class="mobile-menu-button">
#      menu
#     </div>
#     <h2 class="mobile-logo">
#      <a class="mobile-logo-link" href="/">
#       craigslist
#      </a>
#      &gt; housing
#     </h2>
#    </header>
#    <nav class="breadcrumbs-container closed bchead">
#     <form action="/search/eby/apa" data-action="/search/###/apa" id="breadcrumbform" method="get">
#      <input name="is_furnished" type="hidden" value="1">
#       <input name="bedrooms" type="hidden" value="1">
#        <div class="breadbox">
#         <ul class="userlinks">
#          <li class="user post">
#           <a class="no-mobile" href="https://post.craigslist.org/c/sfo?lang=en">
#            post
#           </a>
#           <a class="mobile-only" href="https://post.craigslist.org/c/sfo?lang=en">
#            post to classifieds
#           </a>
#          </li>
#          <li class="user account">
#           <em>
#            [
#           </em>
#           <a class="no-mobile" href="https://accounts.craigslist.org/login/home">
#            account
#           </a>
#           <a class="mobile-only" href="https://accounts.craigslist.org/login/home">
#            my account
#           </a>
#           <em>
#            ]
#           </em>
#          </li>
#          <li class="user fav">
#           <div class="favorites">
#            <a class="favlink" href="#">
#             <span class="n">
#              0
#             </span>
#             <span class="no-mobile">
#              favorites
#             </span>
#            </a>
#           </div>
#          </li>
#         </ul>
#         <ul class="breadcrumbs">
#          <li class="crumb cl">
#           <a href="/">
#            CL
#           </a>
#          </li>
#          <li class="crumb area">
#           <label class="mobile-only submenu-text" for="areaAbb">
#            area
#           </label>
#           <span class="no-js">
#            <a href="/">
#             SF bay area
#            </a>
#           </span>
#           <select class="js-only" id="areaAbb" name="areaAbb">
#            <option value="sfbay">
#             SF bay area
#            </option>
#            <option value="bakersfield">
#             bakersfield
#            </option>
#            <option value="chico">
#             chico
#            </option>
#            <option value="fresno">
#             fresno
#            </option>
#            <option value="goldcountry">
#             gold country
#            </option>
#            <option value="hanford">
#             hanford
#            </option>
#            <option value="mendocino">
#             mendocino co
#            </option>
#            <option value="merced">
#             merced
#            </option>
#            <option value="modesto">
#             modesto
#            </option>
#            <option value="monterey">
#             monterey
#            </option>
#            <option value="redding">
#             redding
#            </option>
#            <option value="reno">
#             reno
#            </option>
#            <option value="sacramento">
#             sacramento
#            </option>
#            <option value="slo">
#             san luis obispo
#            </option>
#            <option value="santamaria">
#             santa maria
#            </option>
#            <option value="stockton">
#             stockton
#            </option>
#            <option value="susanville">
#             susanville
#            </option>
#            <option value="visalia">
#             visalia-tulare
#            </option>
#            <option value="yubasutter">
#             yuba-sutter
#            </option>
#           </select>
#           <span class="breadcrumb-arrow">
#            &gt;
#           </span>
#          </li>
#          <li class="crumb subarea">
#           <label class="mobile-only submenu-text" for="subArea">
#            subarea
#           </label>
#           <select id="subArea" name="subArea">
#            <option value="">
#             all SF bay area
#            </option>
#            <option selected="" value="eby">
#             east bay
#            </option>
#            <option value="nby">
#             north bay
#            </option>
#            <option value="pen">
#             peninsula
#            </option>
#            <option value="sfc">
#             san francisco
#            </option>
#            <option value="scz">
#             santa cruz
#            </option>
#            <option value="sby">
#             south bay
#            </option>
#           </select>
#           <span class="breadcrumb-arrow">
#            &gt;
#           </span>
#          </li>
#          <li class="crumb section">
#           <label class="mobile-only submenu-text" for="catAbb">
#            section
#           </label>
#           <select id="catAbb" name="catAbb">
#            <option value="ccc">
#             community
#            </option>
#            <option value="eee">
#             events
#            </option>
#            <option value="sss">
#             for sale
#            </option>
#            <option value="ggg">
#             gigs
#            </option>
#            <option selected="" value="hhh">
#             housing
#            </option>
#            <option value="jjj">
#             jobs
#            </option>
#            <option value="ppp">
#             personals
#            </option>
#            <option value="rrr">
#             resumes
#            </option>
#            <option value="bbb">
#             services
#            </option>
#           </select>
#           <span class="breadcrumb-arrow">
#            &gt;
#           </span>
#          </li>
#          <li class="crumb category">
#           <div class="mobile-only breadcrumb-labels">
#            category
#           </div>
#           <select class="js-only" id="subcatAbb">
#            <option value="hhh">
#             all
#            </option>
#            <option selected="" value="apa">
#             apts/housing for rent
#            </option>
#            <option value="hou">
#             apts wanted
#            </option>
#            <option value="swp">
#             housing swap
#            </option>
#            <option value="off">
#             office &amp; commercial
#            </option>
#            <option value="prk">
#             parking &amp; storage
#            </option>
#            <option value="reb">
#             real estate - by broker
#            </option>
#            <option value="reo">
#             real estate - by owner
#            </option>
#            <option value="rew">
#             real estate wanted
#            </option>
#            <option value="roo">
#             rooms &amp; shares
#            </option>
#            <option value="sha">
#             rooms wanted
#            </option>
#            <option value="sub">
#             sublets &amp; temporary
#            </option>
#            <option value="sbw">
#             sublet/temp wanted
#            </option>
#            <option value="vac">
#             vacation rentals
#            </option>
#           </select>
#           <span class="no-js">
#            apts/housing for rent
#           </span>
#           <span class="no-js">
#            <input type="submit" value="go"/>
#           </span>
#          </li>
#         </ul>
#        </div>
#        <div class="clearfix">
#        </div>
#       </input>
#      </input>
#     </form>
#    </nav>
#    <div class="middle">
#     <form action="/search/eby/apa" id="searchform">
#      <div class="searchbox">
#       <input id="excats" name="excats" type="hidden">
#        <div class="searchgroup showoptions linklike closed">
#         <span class="open">
#          –
#         </span>
#         <span class="closed">
#          +
#         </span>
#         categories &amp; options
#         <div class="mobile-favorites mobile-only">
#          <div class="favorites">
#           <a class="favlink" href="#">
#            <span class="n">
#             0
#            </span>
#            <span class="no-mobile">
#             favorites
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="searchoptions closed">
#         <script type="text/javascript">
#          <!--
#             var odaCats = {};
#
#         -->
#         </script>
#         <div class="searchgroup categories">
#          <div class="cattitle">
#           <a class="reset" href="/search/eby/apa" title="clear all search parameters">
#            apartments / housing rentals
#           </a>
#          </div>
#         </div>
#         <input id="is_paid" name="is_paid" type="hidden" value="">
#          <div class="searchgroup">
#           <ul>
#            <li>
#             <label class="srchType">
#              <input class="autosubmit" name="srchType" type="checkbox" value="T">
#               search titles only
#              </input>
#             </label>
#            </li>
#            <li>
#             <label class="hasPic">
#              <input class="autosubmit" name="hasPic" type="checkbox" value="1">
#               has image
#              </input>
#             </label>
#            </li>
#            <li>
#             <label class="postedToday">
#              <input class="autosubmit" name="postedToday" type="checkbox" value="1">
#               posted today
#              </input>
#             </label>
#            </li>
#           </ul>
#           <ul class="js-only nearbyAreas ">
#           </ul>
#          </div>
#          <div class="searchgroup">
#           <div class="catfilter attr_picker multilink " data-attr="nh" data-checked-count="0" id="headerattr_nh">
#            <span class="plusminus" id="plusminus_nh">
#             +
#            </span>
#            neighborhoods
#           </div>
#           <ul class="attr_list hideme" id="ul_nh">
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="alameda_46" name="nh" type="checkbox" value="46">
#               alameda
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="albany_/_el_cerrito_47" name="nh" type="checkbox" value="47">
#               albany / el cerrito
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="berkeley_48" name="nh" type="checkbox" value="48">
#               berkeley
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="berkeley_north_/_hills_49" name="nh" type="checkbox" value="49">
#               berkeley north / hills
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="brentwood_/_oakley_142" name="nh" type="checkbox" value="142">
#               brentwood / oakley
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="concord_/_pleasant_hill_/_martinez_51" name="nh" type="checkbox" value="51">
#               concord / pleasant hill / martinez
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="danville_/_san_ramon_52" name="nh" type="checkbox" value="52">
#               danville / san ramon
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="dublin_/_pleasanton_/_livermore_53" name="nh" type="checkbox" value="53">
#               dublin / pleasanton / livermore
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="emeryville_112" name="nh" type="checkbox" value="112">
#               emeryville
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="fairfield_/_vacaville_154" name="nh" type="checkbox" value="154">
#               fairfield / vacaville
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="fremont_/_union_city_/_newark_54" name="nh" type="checkbox" value="54">
#               fremont / union city / newark
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="hayward_/_castro_valley_55" name="nh" type="checkbox" value="55">
#               hayward / castro valley
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="hercules,_pinole,_san_pablo,_el_sob_56" name="nh" type="checkbox" value="56">
#               hercules, pinole, san pablo, el sob
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="lafayette_/_orinda_/_moraga_57" name="nh" type="checkbox" value="57">
#               lafayette / orinda / moraga
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="oakland_downtown_58" name="nh" type="checkbox" value="58">
#               oakland downtown
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="oakland_east_59" name="nh" type="checkbox" value="59">
#               oakland east
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="oakland_hills_/_mills_60" name="nh" type="checkbox" value="60">
#               oakland hills / mills
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="oakland_lake_merritt_/_grand_61" name="nh" type="checkbox" value="61">
#               oakland lake merritt / grand
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="oakland_north_/_temescal_62" name="nh" type="checkbox" value="62">
#               oakland north / temescal
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="oakland_piedmont_/_montclair_63" name="nh" type="checkbox" value="63">
#               oakland piedmont / montclair
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="oakland_rockridge_/_claremont_66" name="nh" type="checkbox" value="66">
#               oakland rockridge / claremont
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="oakland_west_64" name="nh" type="checkbox" value="64">
#               oakland west
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="pittsburg_/_antioch_113" name="nh" type="checkbox" value="113">
#               pittsburg / antioch
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="richmond_/_point_/_annex_65" name="nh" type="checkbox" value="65">
#               richmond / point / annex
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="san_leandro_67" name="nh" type="checkbox" value="67">
#               san leandro
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="vallejo_/_benicia_68" name="nh" type="checkbox" value="68">
#               vallejo / benicia
#              </input>
#             </label>
#            </li>
#            <li class="attr_nh ">
#             <label data-attr="nh">
#              <input class="multi_checkbox multi_nh" data-attr="nh" id="walnut_creek_69" name="nh" type="checkbox" value="69">
#               walnut creek
#              </input>
#             </label>
#            </li>
#            <li class="selectall js-only attr_nh ">
#             <label>
#              <input class="selectallcb multi_checkbox" data-attr="nh" type="checkbox">
#               <span class="all select_all_nh">
#                select all
#               </span>
#               <span class="none deselect_all_nh">
#                deselect all
#               </span>
#              </input>
#             </label>
#            </li>
#           </ul>
#          </div>
#          <div class="searchgroup minmax ">
#           <span class="searchfieldlabel">
#            price
#           </span>
#           <input class="flatinput min" name="min_price" placeholder="min" title="whole number, no letters or symbols" type="tel" value="">
#            <input class="flatinput max" name="max_price" placeholder="max" title="whole number, no letters or symbols" type="tel" value="">
#            </input>
#           </input>
#          </div>
#          <div class="searchgroup">
#           <select class="autosubmit" name="bedrooms">
#            <option value="">
#             all bedrooms
#            </option>
#            <option selected="selected" value="1">
#             1+ bedrooms
#            </option>
#            <option value="2">
#             2+ bedrooms
#            </option>
#            <option value="3">
#             3+ bedrooms
#            </option>
#            <option value="4">
#             4+ bedrooms
#            </option>
#            <option value="5">
#             5+ bedrooms
#            </option>
#            <option value="6">
#             6+ bedrooms
#            </option>
#            <option value="7">
#             7+ bedrooms
#            </option>
#            <option value="8">
#             8+ bedrooms
#            </option>
#           </select>
#           <br>
#            <select class="autosubmit" name="bathrooms">
#             <option value="">
#              all bathrooms
#             </option>
#             <option value="1">
#              1+ bathrooms
#             </option>
#             <option value="2">
#              2+ bathrooms
#             </option>
#             <option value="3">
#              3+ bathrooms
#             </option>
#             <option value="4">
#              4+ bathrooms
#             </option>
#             <option value="5">
#              5+ bathrooms
#             </option>
#             <option value="6">
#              6+ bathrooms
#             </option>
#             <option value="7">
#              7+ bathrooms
#             </option>
#             <option value="8">
#              8+ bathrooms
#             </option>
#            </select>
#           </br>
#          </div>
#          <div class="searchgroup minmax ">
#           <span class="searchfieldlabel">
#            ft
#            <sup>
#             2
#            </sup>
#           </span>
#           <input class="flatinput min" name="minSqft" placeholder="min" title="whole number, no letters or symbols" type="tel" value="">
#            <input class="flatinput max" name="maxSqft" placeholder="max" title="whole number, no letters or symbols" type="tel" value="">
#            </input>
#           </input>
#          </div>
#          <div class="searchgroup">
#           <label class="pets_cat">
#            <input class="autosubmit" name="pets_cat" type="checkbox" value="1">
#             cats ok
#            </input>
#           </label>
#           <br>
#            <label class="pets_dog">
#             <input class="autosubmit" name="pets_dog" type="checkbox" value="1">
#              dogs ok
#             </input>
#            </label>
#            <br>
#             <label class="is_furnished">
#              <input checked="checked" class="autosubmit" name="is_furnished" type="checkbox" value="1">
#               furnished
#              </input>
#             </label>
#             <br>
#              <label class="no_smoking">
#               <input class="autosubmit" name="no_smoking" type="checkbox" value="1">
#                no smoking
#               </input>
#              </label>
#              <br>
#               <label class="wheelchaccess">
#                <input class="autosubmit" name="wheelchaccess" type="checkbox" value="1">
#                 wheelchair access
#                </input>
#               </label>
#               <br/>
#              </br>
#             </br>
#            </br>
#           </br>
#          </div>
#          <div class="searchgroup">
#           <div class="catfilter attr_picker multilink " data-attr="housing_type" data-checked-count="0" id="headerattr_housing_type">
#            <span class="plusminus" id="plusminus_housing_type">
#             +
#            </span>
#            housing type
#           </div>
#           <ul class="attr_list hideme" id="ul_housing_type">
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="apartment_1" name="housing_type" type="checkbox" value="1">
#               apartment
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="condo_2" name="housing_type" type="checkbox" value="2">
#               condo
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="cottage/cabin_3" name="housing_type" type="checkbox" value="3">
#               cottage/cabin
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="duplex_4" name="housing_type" type="checkbox" value="4">
#               duplex
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="flat_5" name="housing_type" type="checkbox" value="5">
#               flat
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="house_6" name="housing_type" type="checkbox" value="6">
#               house
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="in-law_7" name="housing_type" type="checkbox" value="7">
#               in-law
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="loft_8" name="housing_type" type="checkbox" value="8">
#               loft
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="townhouse_9" name="housing_type" type="checkbox" value="9">
#               townhouse
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="manufactured_10" name="housing_type" type="checkbox" value="10">
#               manufactured
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="assisted_living_11" name="housing_type" type="checkbox" value="11">
#               assisted living
#              </input>
#             </label>
#            </li>
#            <li class="attr_housing_type ">
#             <label data-attr="housing_type">
#              <input class="multi_checkbox multi_housing_type" data-attr="housing_type" id="land_12" name="housing_type" type="checkbox" value="12">
#               land
#              </input>
#             </label>
#            </li>
#            <li class="selectall js-only attr_housing_type ">
#             <label>
#              <input class="selectallcb multi_checkbox" data-attr="housing_type" type="checkbox">
#               <span class="all select_all_housing_type">
#                select all
#               </span>
#               <span class="none deselect_all_housing_type">
#                deselect all
#               </span>
#              </input>
#             </label>
#            </li>
#           </ul>
#           <div class="catfilter attr_picker multilink " data-attr="laundry" data-checked-count="0" id="headerattr_laundry">
#            <span class="plusminus" id="plusminus_laundry">
#             +
#            </span>
#            laundry
#           </div>
#           <ul class="attr_list hideme" id="ul_laundry">
#            <li class="attr_laundry ">
#             <label data-attr="laundry">
#              <input class="multi_checkbox multi_laundry" data-attr="laundry" id="w/d_in_unit_1" name="laundry" type="checkbox" value="1">
#               w/d in unit
#              </input>
#             </label>
#            </li>
#            <li class="attr_laundry ">
#             <label data-attr="laundry">
#              <input class="multi_checkbox multi_laundry" data-attr="laundry" id="w/d_hookups_4" name="laundry" type="checkbox" value="4">
#               w/d hookups
#              </input>
#             </label>
#            </li>
#            <li class="attr_laundry ">
#             <label data-attr="laundry">
#              <input class="multi_checkbox multi_laundry" data-attr="laundry" id="laundry_in_bldg_2" name="laundry" type="checkbox" value="2">
#               laundry in bldg
#              </input>
#             </label>
#            </li>
#            <li class="attr_laundry ">
#             <label data-attr="laundry">
#              <input class="multi_checkbox multi_laundry" data-attr="laundry" id="laundry_on_site_3" name="laundry" type="checkbox" value="3">
#               laundry on site
#              </input>
#             </label>
#            </li>
#            <li class="attr_laundry ">
#             <label data-attr="laundry">
#              <input class="multi_checkbox multi_laundry" data-attr="laundry" id="no_laundry_on_site_5" name="laundry" type="checkbox" value="5">
#               no laundry on site
#              </input>
#             </label>
#            </li>
#           </ul>
#           <div class="catfilter attr_picker multilink " data-attr="parking" data-checked-count="0" id="headerattr_parking">
#            <span class="plusminus" id="plusminus_parking">
#             +
#            </span>
#            parking
#           </div>
#           <ul class="attr_list hideme" id="ul_parking">
#            <li class="attr_parking ">
#             <label data-attr="parking">
#              <input class="multi_checkbox multi_parking" data-attr="parking" id="carport_1" name="parking" type="checkbox" value="1">
#               carport
#              </input>
#             </label>
#            </li>
#            <li class="attr_parking ">
#             <label data-attr="parking">
#              <input class="multi_checkbox multi_parking" data-attr="parking" id="attached_garage_2" name="parking" type="checkbox" value="2">
#               attached garage
#              </input>
#             </label>
#            </li>
#            <li class="attr_parking ">
#             <label data-attr="parking">
#              <input class="multi_checkbox multi_parking" data-attr="parking" id="detached_garage_3" name="parking" type="checkbox" value="3">
#               detached garage
#              </input>
#             </label>
#            </li>
#            <li class="attr_parking ">
#             <label data-attr="parking">
#              <input class="multi_checkbox multi_parking" data-attr="parking" id="off-street_parking_4" name="parking" type="checkbox" value="4">
#               off-street parking
#              </input>
#             </label>
#            </li>
#            <li class="attr_parking ">
#             <label data-attr="parking">
#              <input class="multi_checkbox multi_parking" data-attr="parking" id="street_parking_5" name="parking" type="checkbox" value="5">
#               street parking
#              </input>
#             </label>
#            </li>
#            <li class="attr_parking ">
#             <label data-attr="parking">
#              <input class="multi_checkbox multi_parking" data-attr="parking" id="valet_parking_6" name="parking" type="checkbox" value="6">
#               valet parking
#              </input>
#             </label>
#            </li>
#            <li class="attr_parking ">
#             <label data-attr="parking">
#              <input class="multi_checkbox multi_parking" data-attr="parking" id="no_parking_7" name="parking" type="checkbox" value="7">
#               no parking
#              </input>
#             </label>
#            </li>
#            <li class="selectall js-only attr_parking ">
#             <label>
#              <input class="selectallcb multi_checkbox" data-attr="parking" type="checkbox">
#               <span class="all select_all_parking">
#                select all
#               </span>
#               <span class="none deselect_all_parking">
#                deselect all
#               </span>
#              </input>
#             </label>
#            </li>
#           </ul>
#          </div>
#          <div class="searchgroup">
#           <div class="label">
#            open house date
#           </div>
#           <select class="autosubmit" id="sale_date" name="sale_date">
#            <option>
#            </option>
#            <option value="2015-08-21">
#             aug 21 - today
#            </option>
#            <option value="2015-08-22">
#             aug 22 - tomorrow
#            </option>
#            <option value="2015-08-23">
#             aug 23 - sunday
#            </option>
#            <option value="2015-08-24">
#             aug 24 - monday
#            </option>
#            <option value="2015-08-25">
#             aug 25 - tuesday
#            </option>
#            <option value="2015-08-26">
#             aug 26 - wednesday
#            </option>
#            <option value="2015-08-27">
#             aug 27 - thursday
#            </option>
#            <option value="2015-08-28">
#             aug 28 - friday
#            </option>
#            <option value="2015-08-29">
#             aug 29 - saturday
#            </option>
#            <option value="2015-08-30">
#             aug 30 - sunday
#            </option>
#            <option value="2015-08-31">
#             aug 31 - monday
#            </option>
#            <option value="2015-09-01">
#             sep 1 - tuesday
#            </option>
#            <option value="2015-09-02">
#             sep 2 - wednesday
#            </option>
#            <option value="2015-09-03">
#             sep 3 - thursday
#            </option>
#           </select>
#          </div>
#          <div class="searchgroup resetsearch">
#           <a class="reset linklike" href="/search/eby/apa" title="clear all search parameters">
#            reset
#           </a>
#           <button class="searchlink linklike" type="submit">
#            search
#           </button>
#          </div>
#         </input>
#        </div>
#        <div class="no-mobile">
#        </div>
#       </input>
#      </div>
#      <div class="rightpane">
#       <div class="querybox">
#        <span class="form-tab js-only">
#         <span class="search-open" title="hide search">
#          «
#         </span>
#         <span class="search-closed" title="show search">
#          »
#         </span>
#        </span>
#        <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search apartments / housing rentals" type="text" value="">
#         <button class="searchbtn" type="submit">
#          <span class="searchicon">
#          </span>
#         </button>
#         <div class="savealert">
#          <a class="saveme no-mobile" data-action="alert" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Falert%3FURL%3Dhttps%253A%252F%252Fsfbay%252Ecraigslist%252Eorg%252Fsearch%252Feby%252Fapa%253Fbedrooms%253D1%2526is%255Ffurnished%253D1" title="save this search with email alerts ">
#           email alert
#          </a>
#          <a class="saveme no-mobile" data-action="save" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Fsfbay%252Ecraigslist%252Eorg%252Fsearch%252Feby%252Fapa%253Fbedrooms%253D1%2526is%255Ffurnished%253D1" title="save this search ">
#           save search
#          </a>
#          <a class="saveme mobile-only" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Falert%3FURL%3Dhttps%253A%252F%252Fsfbay%252Ecraigslist%252Eorg%252Fsearch%252Feby%252Fapa%253Fbedrooms%253D1%2526is%255Ffurnished%253D1">
#           search alert
#          </a>
#         </div>
#        </input>
#       </div>
#       <div class="toc_legend">
#        <div class="center">
#         <div class="tocview">
#          <span class="buttongroup js-only">
#           <a class="mode button" data-view="list" href="#list" id="listview" title="show results in a list">
#            list
#           </a>
#           <a class="mode button" data-view="pic" href="#pic" id="picview" title="show results in a list with thumbnail pictures">
#            thumb
#           </a>
#           <a class="mode button" data-view="grid" href="#grid" id="gridview" title="show results side-by-side with larger pictures">
#            gallery
#           </a>
#           <a class="mode button" data-view="map" href="#map" id="mapview" title="show results on a map">
#            map
#           </a>
#          </span>
#         </div>
#         <div class="tocsort">
#          <span class="buttongroup">
#           <span class="button sel">
#            newest
#           </span>
#           <a class="button" href="/search/eby/apa?sort=priceasc&amp;bedrooms=1&amp;is_furnished=1" title="sort by price, lowest to highest">
#            <span class="pricesort">
#             <span class="pricesort">
#              $
#             </span>
#             $
#            </span>
#            $
#           </a>
#           <a class="button" href="/search/eby/apa?sort=pricedsc&amp;bedrooms=1&amp;is_furnished=1" title="sort by price, highest to lowest">
#            $
#            <span class="pricesort">
#             $
#             <span class="pricesort">
#              $
#             </span>
#            </span>
#           </a>
#          </span>
#         </div>
#         <span class="paginator buttongroup firstpage lastpage">
#          <span class="resulttotal">
#           displaying
#           <span class="displaycount">
#            ...
#           </span>
#           <span class="of-total">
#            of
#            <span class="totalcount">
#             84
#            </span>
#           </span>
#           postings
#          </span>
#          <span class="buttons">
#           <a class="button first" href="/search/eby/apa?bedrooms=1&amp;is_furnished=1" title="first page">
#            &lt;&lt;
#           </a>
#           <span class="button first" title="first page">
#            &lt;&lt;
#           </span>
#           <a class="button prev" href="/search/eby/apa?bedrooms=1&amp;is_furnished=1" title="previous page">
#            &lt; prev
#           </a>
#           <span class="button prev" title="previous page">
#            &lt; prev
#           </span>
#           <span class="button pagenum">
#            <span class="range">
#             <span class="rangeFrom">
#              1
#             </span>
#             to
#             <span class="rangeTo">
#              84
#             </span>
#            </span>
#            <span class="of-total">
#             of
#             <span class="totalcount">
#              84
#             </span>
#            </span>
#           </span>
#           <a class="button next" href="/search/eby/apa?s=84&amp;bedrooms=1&amp;is_furnished=1" title="next page">
#            next &gt;
#           </a>
#           <span class="button next" title="next page">
#            next &gt;
#           </span>
#          </span>
#         </span>
#        </div>
#       </div>
#       <div class="content">
#        <section class="favlistsection">
#         <section class="favlistinfo">
#         </section>
#        </section>
#        <p class="row" data-pid="5183961779">
#         <a class="i" data-ids="0:00f0f_4VOyuRKg1NL,0:00d0d_cPsrSIKZ65M,0:00101_49n5wQ2FpPz,0:00L0L_cdHq3zu3Vg5,0:00H0H_lGZouxLZlnS" href="/eby/apa/5183961779.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-08-21 12:13" title="Fri 21 Aug 12:13:51 PM">
#            Aug 21
#           </time>
#           <a class="hdrlnk" data-id="5183961779" href="/eby/apa/5183961779.html">
#            North Berkeley Furnished In-Law
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $990
#           </span>
#           <span class="housing">
#            / 1br -
#           </span>
#           <span class="pnr">
#            <small>
#             (berkeley north / hills)
#            </small>
#            <span class="px">
#             <span class="p">
#              pic
#              <span class="maptag" data-pid="5183961779">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5183961779" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5183961779" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5183952420" data-repost-of="3041402814">
#         <a class="i" href="/eby/apa/5183952420.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-08-21 12:08" title="Fri 21 Aug 12:08:58 PM">
#            Aug 21
#           </time>
#           <a class="hdrlnk" data-id="5183952420" href="/eby/apa/5183952420.html">
#            Sunny Townhouse unit on quiet street can be furnished
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $2300
#           </span>
#           <span class="housing">
#            / 2br - 700ft
#            <sup>
#             2
#            </sup>
#            -
#           </span>
#           <span class="pnr">
#            <small>
#             (berkeley)
#            </small>
#            <span class="px">
#             <span class="p">
#              <span class="maptag" data-pid="5183952420">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5183952420" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5183952420" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5183881696">
#         <a class="i" data-ids="0:00r0r_cTxkpzEvod8,0:00o0o_a4xg37PaxFt,0:00s0s_4CNMAdBCluS,0:00G0G_kOol9aNIFQM,0:00C0C_1TscT7X7zYd,0:00d0d_lfUXtL9AwWG" href="/eby/apa/5183881696.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-08-21 11:29" title="Fri 21 Aug 11:29:57 AM">
#            Aug 21
#           </time>
#           <a class="hdrlnk" data-id="5183881696" href="/eby/apa/5183881696.html">
#            Modern 1br Condo Furnished Avail Sept 10 - Nov 10
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $2450
#           </span>
#           <span class="housing">
#            / 1br - 800ft
#            <sup>
#             2
#            </sup>
#            -
#           </span>
#           <span class="pnr">
#            <small>
#             (emeryville)
#            </small>
#            <span class="px">
#             <span class="p">
#              pic
#              <span class="maptag" data-pid="5183881696">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5183881696" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5183881696" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5183619662">
#         <a class="i" data-ids="0:00f0f_5AOqcodDiee" href="/eby/apa/5183619662.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-08-21 11:07" title="Fri 21 Aug 11:07:52 AM">
#            Aug 21
#           </time>
#           <a class="hdrlnk" data-id="5183619662" href="/eby/apa/5183619662.html">
#            Fantastic deal for this 3 bedrooms house
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $2415
#           </span>
#           <span class="housing">
#            / 3br - 1148ft
#            <sup>
#             2
#            </sup>
#            -
#           </span>
#           <span class="pnr">
#            <small>
#             (fremont / union city / newark)
#            </small>
#            <span class="px">
#             <span class="p">
#              pic
#              <span class="maptag" data-pid="5183619662">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
# ...
#           </span>
#           <span class="pnr">
#            <small>
#             <span class="nearby" title="SF bay area">
#              (sfo &gt; san jose downtown)
#             </span>
#            </small>
#            <span class="px">
#             <span class="p">
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5173780064" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5173780064" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5183442489">
#         <a class="i" href="//sacramento.craigslist.org/apa/5183442489.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-08-21 07:42" title="Fri 21 Aug 07:42:10 AM">
#            Aug 21
#           </time>
#           <a class="hdrlnk" data-id="5183442489" href="//sacramento.craigslist.org/apa/5183442489.html">
#            On Sabbatical - semi-furnished house available
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $1750
#           </span>
#           <span class="housing">
#            / 3br - 1200ft
#            <sup>
#             2
#            </sup>
#            -
#           </span>
#           <span class="pnr">
#            <small>
#             <span class="nearby" title="sacramento">
#              (sac &gt; Davis)
#             </span>
#            </small>
#            <span class="px">
#             <span class="p">
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5183442489" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5183442489" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5163688139" data-repost-of="5135874993">
#         <a class="i" data-ids="0:00i0i_cI0aj9cvCgr,0:00h0h_5r7tCRfNy41,0:00e0e_iXYK1MWTExD,0:00S0S_9NXwKHrROJE,0:00V0V_ixM1dL8DgwE,0:00b0b_jYb9awHzecl,0:00a0a_lL8cykdPacv,0:01717_6QX16OnSMP2,0:01717_barq6lNGzeR,0:00808_4uwlatjAeL1,0:00W0W_daCskJzr8xe,0:00C0C_3IgxetFsDRY,0:00606_fOr5o0pf7Cf,0:00M0M_4Yuqyf06nLQ,0:01313_adyKEZcO9sE,0:00606_4fuBSTCZb20,0:00l0l_eLj32PEW2S,0:01010_eAvHaoOPXZn,0:00y0y_fEQYOGnsWq6,0:00D0D_ItleaaafKC" href="//sfbay.craigslist.org/sby/apa/5163688139.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-08-21 07:40" title="Fri 21 Aug 07:40:11 AM">
#            Aug 21
#           </time>
#           <a class="hdrlnk" data-id="5163688139" href="//sfbay.craigslist.org/sby/apa/5163688139.html">
#            Westgate: Newly Remodeled Apt
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $4000
#           </span>
#           <span class="housing">
#            / 1br - 608ft
#            <sup>
#             2
#            </sup>
#            -
#           </span>
#           <span class="pnr">
#            <small>
#             <span class="nearby" title="SF bay area">
#              (sfo &gt; san jose west)
#             </span>
#            </small>
#            <span class="px">
#             <span class="p">
#              pic
#              <span class="maptag" data-pid="5163688139">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5163688139" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5163688139" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5148373355">
#         <a class="i" data-ids="0:00i0i_f46plPkxrlJ,0:01313_25S1t4RzFlp,0:00o0o_riZF6Yl2IC,0:00101_iZ5YXl937wp,0:00k0k_hHXZZSd6Snm,0:00404_bh8r0SiKVxR,0:00606_ek5HMO5gUSk" href="//sfbay.craigslist.org/pen/apa/5148373355.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-08-21 07:38" title="Fri 21 Aug 07:38:30 AM">
#            Aug 21
#           </time>
#           <a class="hdrlnk" data-id="5148373355" href="//sfbay.craigslist.org/pen/apa/5148373355.html">
#            Furnished Woodlake 1bd, FREE Utilities-Cable-Internet - Flex Lease - Oct 1
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $2999
#           </span>
#           <span class="housing">
#            / 1br - 693ft
#            <sup>
#             2
#            </sup>
#            -
#           </span>
#           <span class="pnr">
#            <small>
#             <span class="nearby" title="SF bay area">
#              (sfo &gt; san mateo)
#             </span>
#            </small>
#            <span class="px">
#             <span class="p">
#              pic
#              <span class="maptag" data-pid="5148373355">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5148373355" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5148373355" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <p class="row" data-pid="5145702620">
#         <a class="i" data-ids="0:00n0n_cqYBHhFVZXe,0:00N0N_cozAdfCy43k,0:00B0B_l6FWVahi2DK,0:00Z0Z_cV9vP67hT7f,0:01313_jqFVKtJPRYO,0:00f0f_4ybf5DN8wkl,0:01616_1MvFLbCQPIA,0:01212_9d4iJERkaxU,0:00C0C_c595YrwwKyx,0:00z0z_1UrCxz3ZJ4I,0:00r0r_mkwxYCepe5,0:00A0A_l0a9ASXHd55,0:00v0v_67EazZTfhYN,0:00f0f_1AGqn6HpAPT,0:00x0x_f9RcYqKLBjI,0:00u0u_gEhDsL0C94Z,0:00p0p_d2dLQlFAqse" href="//sfbay.craigslist.org/sfc/apa/5145702620.html">
#         </a>
#         <span class="txt">
#          <span class="star">
#          </span>
#          <span class="pl">
#           <time datetime="2015-08-21 07:09" title="Fri 21 Aug 07:09:15 AM">
#            Aug 21
#           </time>
#           <a class="hdrlnk" data-id="5145702620" href="//sfbay.craigslist.org/sfc/apa/5145702620.html">
#            Victorian Charm in Hayes Valley!! LOTS of Tech Buses; Easy City Commute
#           </a>
#          </span>
#          <span class="l2">
#           <span class="price">
#            $5980
#           </span>
#           <span class="housing">
#            / 3br -
#           </span>
#           <span class="pnr">
#            <small>
#             <span class="nearby" title="SF bay area">
#              (sfo &gt; hayes valley)
#             </span>
#            </small>
#            <span class="px">
#             <span class="p">
#              pic
#              <span class="maptag" data-pid="5145702620">
#               map
#              </span>
#             </span>
#            </span>
#           </span>
#          </span>
#          <span class="js-only banish-unbanish no-mobile">
#           [
#           <a class="banish" data-pid="5145702620" title="hide">
#            x
#           </a>
#           <a class="unbanish linklike" data-pid="5145702620" title="unhide">
#            undo
#           </a>
#           ]
#          </span>
#         </span>
#        </p>
#        <div data-arealat="37.500000" data-arealon="-122.250000" id="mapcontainer">
#         <div id="noresult_overlay">
#         </div>
#         <div id="noresult_text">
#          <span class="message">
#           No mappable items found
#          </span>
#         </div>
#         <div class="loading" id="map">
#          <div class="closeFS">
#           ×
#          </div>
#         </div>
#        </div>
#        <div class="toc_legend bottom">
#         <div class="center">
#          <div class="tocview">
#           <span class="buttongroup">
#            <a class="backtotop button" href="#pagecontainer">
#             ^ back to top
#            </a>
#           </span>
#          </div>
#          <div class="tocsort">
#           <span class="buttongroup">
#            <a class="backtotop button" href="#pagecontainer">
#             ^ back to top
#            </a>
#           </span>
#          </div>
#          <span class="paginator buttongroup firstpage lastpage">
#           <span class="resulttotal">
#            displaying
#            <span class="displaycount">
#             ...
#            </span>
#            <span class="of-total">
#             of
#             <span class="totalcount">
#              84
#             </span>
#            </span>
#            postings
#           </span>
#           <span class="buttons">
#            <a class="button first" href="/search/eby/apa?bedrooms=1&amp;is_furnished=1" title="first page">
#             &lt;&lt;
#            </a>
#            <span class="button first" title="first page">
#             &lt;&lt;
#            </span>
#            <a class="button prev" href="/search/eby/apa?bedrooms=1&amp;is_furnished=1" title="previous page">
#             &lt; prev
#            </a>
#            <span class="button prev" title="previous page">
#             &lt; prev
#            </span>
#            <span class="button pagenum">
#             <span class="range">
#              <span class="rangeFrom">
#               1
#              </span>
#              to
#              <span class="rangeTo">
#               84
#              </span>
#             </span>
#             <span class="of-total">
#              of
#              <span class="totalcount">
#               84
#              </span>
#             </span>
#            </span>
#            <a class="button next" href="/search/eby/apa?s=84&amp;bedrooms=1&amp;is_furnished=1" title="next page">
#             next &gt;
#            </a>
#            <span class="button next" title="next page">
#             next &gt;
#            </span>
#           </span>
#          </span>
#         </div>
#        </div>
#       </div>
#      </div>
#      <section class="blurbs">
#      </section>
#      <div id="floater">
#       <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif">
#        <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif">
#        </img>
#       </img>
#      </div>
#      <template id="gallerycarousel">
#       <div class="sliderinfo">
#       </div>
#       <div class="sliderback arrow">
#        &lt;
#       </div>
#       <div class="sliderforward arrow">
#        &gt;
#       </div>
#      </template>
#     </form>
#    </div>
#    <div class="mobile-only">
#    </div>
#    <div class="discards footstool no-mobile js-only">
#     <p>
#      <strong class="hidden_count">
#      </strong>
#      hidden
#     </p>
#     <!-- show if there is at least one hidden thing and the hidden are NOT revealed -->
#     <div class="show-discards-link linklike" role="button" tabindex="0">
#      click to show
#     </div>
#     <!-- show if there is at least one hidden thing and the hidden ARE not revealed -->
#     <div class="hide-discards-link linklike" role="button" tabindex="0">
#      click to hide
#     </div>
#    </div>
#    <footer>
#     <span class="rss">
#      <a class="l" href="https://sfbay.craigslist.org/search/eby/apa?bedrooms=1&amp;is_furnished=1&amp;format=rss">
#       RSS
#      </a>
#      <a href="http://www.craigslist.org/about/rss">
#       (?)
#      </a>
#      <br>
#      </br>
#     </span>
#     <ul class="clfooter">
#      <li>
#       © 2015
#       <span class="desktop">
#        craigslist
#       </span>
#       <span class="mobile">
#        CL
#       </span>
#      </li>
#      <li>
#       <a href="//www.craigslist.org/about/help/">
#        help
#       </a>
#      </li>
#      <li>
#       <a href="//www.craigslist.org/about/scams">
#        safety
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="//www.craigslist.org/about/privacy.policy">
#        privacy
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://forums.craigslist.org/?forumID=8">
#        feedback
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="//www.craigslist.org/about/craigslist_is_hiring">
#        cl jobs
#       </a>
#      </li>
#      <li>
#       <a href="//www.craigslist.org/about/terms.of.use">
#        terms
#       </a>
#      </li>
#      <li>
#       <a href="//www.craigslist.org/about/">
#        about
#       </a>
#      </li>
#      <li class="fsel desktop linklike" data-mode="mobile">
#       mobile
#      </li>
#      <li class="fsel mobile linklike" data-mode="regular">
#       desktop
#      </li>
#     </ul>
#    </footer>
#   </section>
#   <script src="//www.craigslist.org/js/general-concat.min.js?v=7db13e14edce1be55946b402b4ae2132" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--
#         var iframe = document.createElement('iframe');
#         iframe.style.display = 'none';
#         iframe.src = '//www.' + CL.url.baseDomain + '/static/localstorage.html?v=51a29e41f8e978141e4085ed4a77d170';
#         document.body.insertBefore(iframe, null);
#     -->
#   </script>
#   <script id="clustertemplate" type="text/template">
#    <li class="posting {visited}" data-id="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#          <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#          <span class="bedrooms">{BedroomsContent}</span>
#          <span class="postingtitle"><a>{PostingTitle}</a></span>
#          <span class="js-only map-banish-unbanish no-mobile" data-pid="{PostingID}">
#           [<a class="banish" id="banisher" data-pid="{PostingID}" title="hide">x</a><a class="unbanish" id="unbanisher" data-pid="{PostingID}" title="unhide">undo</a>]
#          </span>
#         </div>
#     </li>
#   </script>
#   <script id="postingtemplate" type="text/template">
#    <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             <button class="back" type="button">&lt;</button> back to posting list
#         </div>
#         <div class="title">
#             <span class="star" data-pid="{PostingID}"></span>
#             <span class="postingtitle">
#               <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish no-mobile single">
#                   [<a class="banish" id="banisher" data-pid="{PostingID}" title="hide">x</a><a class="unbanish" id="unbanisher" data-pid="{PostingID}" title="unhide">undo</a>]
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer">
#             <div class="slidernav">
#                 <span class="sliderback">&lt;</span><span class="sliderinfo"></span><span class="sliderforward">&gt;</span>
#             </div>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <abbr class="date timeago" title="{isoPostedDate}">{humanPostedDate}</abbr>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
#   </script>
#   <script id="popuptemplate" type="text/template">
#    <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
#   </script>
#   <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=431734abb8c23b754a7a297580b0fa43" type="text/javascript">
#   </script>
#   <script src="//www.craigslist.org/js/tocs-concat.min.js?v=0f57d11a76a5069301d6356de9e3f43d" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
# find_all will pull entries that fit your search criteria.
# Note that we have to use brackets to define the `attrs` dictionary
# Because "class" is a special word in python, so we need to give a string.
apts = html.find_all('p', attrs={'class': 'row'})
print(len(apts))
# Out:
# 172

# %% [markdown]
# Now let's look inside the values of a single apartment listing:

# %%
# We can see that there's a consistent structure to a listing.
# There is a 'time', a 'name', a 'housing' field with size/n_brs, etc.
this_appt = apts[15]
print(this_appt.prettify())
# Out:
# <p class="row" data-pid="5174901019">
#  <a class="i" data-ids="0:00y0y_jnV0GbKU8wr,0:00F0F_46wpYRWp65x,0:00U0U_kkuGW85sCTo,0:00303_d8Dr5p0xymO" href="/eby/apa/5174901019.html">
#  </a>
#  <span class="txt">
#   <span class="star">
#   </span>
#   <span class="pl">
#    <time datetime="2015-08-20 20:04" title="Thu 20 Aug 08:04:54 PM">
#     Aug 20
#    </time>
#    <a class="hdrlnk" data-id="5174901019" href="/eby/apa/5174901019.html">
#     Spacious 1 bed in-law with view of Golden Gate Bridge
#    </a>
#   </span>
#   <span class="l2">
#    <span class="price">
#     $2000
#    </span>
#    <span class="housing">
#     / 1br - 738ft
#     <sup>
#      2
#     </sup>
#     -
#    </span>
#    <span class="pnr">
#     <small>
#      (albany / el cerrito)
#     </small>
#     <span class="px">
#      <span class="p">
#       pic
#       <span class="maptag" data-pid="5174901019">
#        map
#       </span>
#      </span>
#     </span>
#    </span>
#   </span>
#   <span class="js-only banish-unbanish no-mobile">
#    [
#    <a class="banish" data-pid="5174901019" title="hide">
#     x
#    </a>
#    <a class="unbanish linklike" data-pid="5174901019" title="unhide">
#     undo
#    </a>
#    ]
#   </span>
#  </span>
# </p>

# %%
# So now we'll pull out a couple of things we might be interested in:
# It looks like "housing" contains size information. We'll pull that.
# Note that `findAll` returns a list, since there's only one entry in
# this HTML, we'll just pull the first item.
size = this_appt.findAll(attrs={'class': 'housing'})[0].text
print(size)
# Out:
# / 1br - 738ft2 -

# %% [markdown]
# We can query split this into n_bedrooms and the size. However, note that sometimes one of these features might be missing. So we'll use an `if` statement to try and capture this variability:

# %%
def find_size_and_brs(size):
    split = size.strip('/- ').split(' - ')
    if len(split) == 2:
        n_brs = split[0].replace('br', '')
        this_size = split[1].replace('ft2', '')
    elif 'br' in split[0]:
        # It's the n_bedrooms
        n_brs = split[0].replace('br', '')
        this_size = np.nan
    elif 'ft2' in split[0]:
        # It's the size
        this_size = split[0].replace('ft2', '')
        n_brs = np.nan
    return float(this_size), float(n_brs)
this_size, n_brs = find_size_and_brs(size)

# %%
# Now we'll also pull a few other things:
this_time = this_appt.find('time')['datetime']
this_time = pd.to_datetime(this_time)
this_price = float(this_appt.find('span', {'class': 'price'}).text.strip('$'))

# %%
# Now we've got the n_bedrooms, size, price, and time of listing
print('\n'.join([str(i) for i in [this_size, n_brs, this_time, this_price]]))
# Out:
# 738.0
# 1.0
# 2015-08-20 20:04:00
# 2000.0

# %% [markdown]
# Cool - so now we've got some useful information about one listing. Now let's loop through many listings across several locations.
#
# It looks like there is a "city code" that distinguishes where you're searching. Here is a **not** up to date list: [link](https://sites.google.com/site/clsiteinfo/city-site-code-sort)
#
# Within the Bay Area, there are also a lot of sub-regional locations, which we'll define here, there loop through them all.
#
# Note that the `s` parameter tells Craiglist where to start in terms of the number of results given back. E.g., if s==100, then it starts at the 100th entry.

# %%
loc_prefixes = ['eby', 'nby', 'sfc', 'sby', 'scz']

# %% [markdown]
# We'll define a few helper functions to handle edge cases and make sure that we don't get any errors.

# %%
def find_prices(results):
    prices = []
    for rw in results:
        price = rw.find('span', {'class': 'price'})
        if price is not None:
            price = float(price.text.strip('$'))
        else:
            price = np.nan
        prices.append(price)
    return prices

def find_times(results):
    times = []
    for rw in apts:
        if time is not None:
            time = time['datetime']
            time = pd.to_datetime(time)
        else:
            time = np.nan
        times.append(time)
    return times

# %% [markdown]
# Now we're ready to go. We'll loop through all of our locations, and pull a number of entries for each one. We'll use a pandas dataframe to store everything, because this will be useful for future analysis.

# %%
# Now loop through all of this and store the results
results = []  # We'll store the data here
# Careful with this...too many queries == your IP gets banned temporarily
search_indices = np.arange(0, 300, 100)
for loc in loc_prefixes:
    print loc
    for i in search_indices:
        url = 'http://sfbay.craigslist.org/search/{0}/apa'.format(loc)
        resp = requests.get(url, params={'bedrooms': 1, 's': i})
        txt = bs4(resp.text, 'html.parser')
        apts = txt.findAll(attrs={'class': "row"})
        
        # Find the size of all entries
        size_text = [rw.findAll(attrs={'class': 'housing'})[0].text
                     for rw in apts]
        sizes_brs = [find_size_and_brs(stxt) for stxt in size_text]
        sizes, n_brs = zip(*sizes_brs)  # This unzips into 2 vectors
     
        # Find the time
        time = [pd.to_datetime(rw.find('time')['datetime']) for rw in apts]
        price = find_prices(apts)
        
        # We'll create a dataframe to store all the data
        data = np.array([time, price, sizes, n_brs])
        df = pd.DataFrame(data.T, columns=['time', 'price', 'size', 'brs'])
        df = df.set_index('time')
        
        # Add the location variable to all entries
        df['loc'] = loc
        results.append(df)
        
# Finally, concatenate all the results
results = pd.concat(results, axis=0)
# Out:
# eby
# nby
# sfc
# sby
# scz

# %%
# We'll make sure that the right columns are represented numerically:
results = results.convert_objects(convert_numeric=True)

# %%
# And there you have it:
results.head()
# Out:
#                      price  size  brs  loc
# time
# 2015-08-21 15:15:00   2700   800    1  eby
# 2015-08-21 15:14:00   3342  1305    3  eby
# 2015-08-21 15:13:00   1988   784    1  eby
# 2015-08-21 15:13:00   1968   797    1  eby
# 2015-08-21 15:12:00   1700   850    2  eby

# %%
# Seaborn can help create some pretty plots
import seaborn as sns

# %%
f, (ax_hist, ax_ts) = plt.subplots(2, 1, figsize=(10, 10))
for loc, vals in results.groupby('loc'):
    sns.distplot(vals['price'], label=loc, ax=ax_hist)
    vals.resample('h', how='count')['price'].plot(ax=ax_ts)
    ax_hist.legend()

# %% [markdown]
# **RECAP** - to sum up what we just did:
#
# * We defined the ability to query a website using a custom URL. This is usually the same in structure for website, but the parameter names will be different.
# * We sent a `get` request to Craigslist using the `requests` module of python.
# * We parsed the response using `BeautifulSoup4`.
# * We then looped through a bunch of apartment listings, pulled some relevant data, and combined it all into a cleaned and usable dataframe with `pandas`.
